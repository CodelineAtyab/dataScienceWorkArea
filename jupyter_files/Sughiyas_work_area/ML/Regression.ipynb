# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder, minmax_scale
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('laptopData.csv')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42)
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                Memory  \
# ...

# %%
df_train = df_train.dropna()
df_train.head()
# Out:
#      Company   TypeName Inches             ScreenResolution  \
# 1158  Lenovo   Notebook   15.6            Full HD 1920x1080
# 904   Lenovo   Notebook   15.6  IPS Panel Full HD 1920x1080
# 439     Asus   Notebook   15.6            Full HD 1920x1080
# 581     Dell   Notebook   15.6                     1366x768
# 676     Asus  Ultrabook     14            Full HD 1920x1080
#
#                              Cpu  Ram        Memory                    Gpu  \
# 1158  Intel Core i5 6200U 2.3GHz  8GB  1.0TB Hybrid     AMD Radeon R5 M330
# 904   Intel Core i5 7200U 2.5GHz  8GB     512GB SSD  Intel HD Graphics 620
# 439   Intel Core i5 7200U 2.5GHz  4GB     256GB SSD  Intel HD Graphics 620
# 581   Intel Core i5 7300U 2.6GHz  8GB     500GB HDD  Intel HD Graphics 620
# 676   Intel Core i5 7200U 2.5GHz  8GB     256GB SSD  Intel HD Graphics 620
#
#            OpSys  Weight        Price
# 1158  Windows 10   2.5kg   42010.7472
# 904   Windows 10  1.95kg  104588.1072
# ...

# %%
df_test = df_test.dropna()
df_test.head()
# Out:
#       Company  TypeName Inches             ScreenResolution  \
# 479   Toshiba  Notebook   13.3  IPS Panel Full HD 1920x1080
# 1022       HP  Notebook   13.3  IPS Panel Full HD 1920x1080
# 298    Lenovo  Notebook   15.6            Full HD 1920x1080
# 1265   Lenovo  Notebook   15.6  IPS Panel Full HD 1920x1080
# 582        HP  Notebook   13.3            Full HD 1920x1080
#
#                               Cpu  Ram     Memory                      Gpu  \
# 479    Intel Core i5 7200U 2.5GHz  8GB  256GB SSD    Intel HD Graphics 620
# 1022   Intel Core i5 7200U 2.5GHz  8GB  256GB SSD    Intel HD Graphics 620
# 298   AMD A10-Series 9600P 2.4GHz  6GB    1TB HDD        AMD Radeon R5 430
# 1265  Intel Core i7 6700HQ 2.6GHz  8GB    1TB HDD  Nvidia GeForce GTX 960M
# 582    Intel Core i3 7100U 2.4GHz  4GB  128GB SSD    Intel HD Graphics 620
#
#            OpSys  Weight     Price
# 479   Windows 10  1.05kg  89084.16
# 1022  Windows 10  1.11kg  61218.72
# 298   Windows 10   2.4kg  26586.72
# ...

# %%
#convert weight column to float
df_train['Weight'] = df_train['Weight'].str.replace('kg', ' ')
df_train['Weight'] = pd.to_numeric(df_train['Weight'], errors='coerce')
# Out:
# C:\Users\71538\AppData\Local\Temp\ipykernel_28544\1711777680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Weight'] = df_train['Weight'].str.replace('kg', ' ')
# C:\Users\71538\AppData\Local\Temp\ipykernel_28544\1711777680.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Weight'] = pd.to_numeric(df_train['Weight'], errors='coerce')

# %%
#clean weight and convert to float
df_test['Weight'] = df_test['Weight'].str.replace('kg', ' ')
df_test['Weight'] = pd.to_numeric(df_test['Weight'], errors='coerce')

# %%
df_train[df_train['Weight'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
df_test[df_test['Weight'].isnull()]
# Out:
#     Company   TypeName Inches   ScreenResolution                         Cpu  \
# 208    Dell  Ultrabook   13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#      Ram     Memory                     Gpu       OpSys  Weight     Price
# 208  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10     NaN  77202.72

# %%
df_test.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              1
# Price               0
# dtype: int64

# %%
df_test.loc[208, 'Weight'] = 2.8

# %%
memory_split_train = df_train['Memory'].str.extract(r'(\d+[GB|TB]+) ([A-Za-z]+)')

# %%
memory_split_train[memory_split_train.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
df_train['Memory_Size'] = memory_split_train[0]
df_train['Memory_Type'] = memory_split_train[1]
# Out:
# C:\Users\71538\AppData\Local\Temp\ipykernel_28544\2562497959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Memory_Size'] = memory_split_train[0]
# C:\Users\71538\AppData\Local\Temp\ipykernel_28544\2562497959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Memory_Type'] = memory_split_train[1]

# %%
df_train = df_train.drop('Memory', axis=1)

# %%
memory_split_train = df_test['Memory'].str.extract(r'(\d+[GB|TB]+) ([A-Za-z]+)')

# %%
memory_split_train[memory_split_train.isnull().any(axis=1)]
# Out:
#        0    1
# 770  NaN  NaN

# %%
memory_split_train.loc[770,0] = '512GB'
memory_split_train.loc[770,1] = 'SSD'

# %%
df_test['Memory_Size'] = memory_split_train[0]
df_test['Memory_Type'] = memory_split_train[1]

# %%
df_test = df_test.drop('Memory', axis=1)

# %%
def split_cpu(cpu):
    parts=cpu.split()

    cpu_model = ' '.join(parts[:len(parts)-1])
    cpu_speed = parts[-1]

    return pd.Series([cpu_model, cpu_speed], index=['cpu_model', 'cpu_speed'])

# %%
df_train
