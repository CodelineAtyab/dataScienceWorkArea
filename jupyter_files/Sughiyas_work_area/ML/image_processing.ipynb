# %% [markdown]
# Image Processing

# %%
import cv2
import matplotlib.pyplot as plt

# %%
#save img and read rgb img
img = cv2.imread('dogg.jpg')
plt.imshow(img)

# %%
#output img with window name as 'image'
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img2 = cv2.imread('moon.bmp')
img3 = (img2 +20)%255
plt.imshow(img3)

# %%
import numpy as np
plt.imshow(np.zeros((20, 20, 3))+255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [255.0..255.0].

# %%
grey_img = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
plt.imshow(grey_img, cmap='grey')

# %%
grey = grey_img.T
plt.imshow(grey, cmap='grey')
