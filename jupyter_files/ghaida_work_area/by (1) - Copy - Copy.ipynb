# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

   
df = pd.read_excel(r"C:\Users\71589\Desktop\uncleaned bike sales data.xlsx", sheet_name=0)
 
df.head()
# Out:
#    Sales_Order #       Date  Day     Month  Year  Customer_Age  \
# 0         261695 2021-12-01  1.0  December  2021            39
# 1         261695 2021-12-01  1.0  December  2021            44
# 2         261697 2021-12-02  2.0  December  2021            37
# 3         261698 2021-12-02  2.0  December  2021            31
# 4         261699 2021-12-03  3.0  December  2021            37
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
#   Product_Category    Sub_Category        Product_Description  Order_Quantity  \
# ...

# %%
df.isnull()
# Out:
#     Sales_Order #   Date    Day  Month   Year  Customer_Age  Age_Group  \
# 0           False  False  False  False  False         False      False
# 1           False  False  False  False  False         False      False
# 2           False  False  False  False  False         False      False
# 3           False  False  False  False  False         False      False
# 4           False  False  False  False  False         False      False
# ..            ...    ...    ...    ...    ...           ...        ...
# 84          False  False  False  False  False         False      False
# 85          False  False  False  False  False         False      False
# 86          False  False  False  False  False         False      False
# 87          False  False  False  False  False         False      False
# 88          False  False  False  False  False         False      False
#
#     Customer_Gender  Country  State  Product_Category  Sub_Category  \
# ...

# %%
df.isnull().mean()
# Out:
# Sales_Order #          0.000000
# Date                   0.000000
# Day                    0.011236
# Month                  0.000000
# Year                   0.000000
# Customer_Age           0.000000
# Age_Group              0.011236
# Customer_Gender        0.000000
# Country                0.000000
# State                  0.000000
# Product_Category       0.000000
# Sub_Category           0.000000
# Product_Description    0.011236
# Order_Quantity         0.011236
#  Unit_Cost             0.000000
#  Unit_Price            0.000000
#  Profit                0.000000
#  Cost                  0.000000
# Revenue                0.000000
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Sales_Order #          0
# Date                   0
# Day                    1
# Month                  0
# Year                   0
# Customer_Age           0
# Age_Group              1
# Customer_Gender        0
# Country                0
# State                  0
# Product_Category       0
# Sub_Category           0
# Product_Description    1
# Order_Quantity         1
#  Unit_Cost             0
#  Unit_Price            0
#  Profit                0
#  Cost                  0
# Revenue                0
# dtype: int64

# %%
df.dropna()
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
df.fillna(method=('ffill'))
# Out:
# C:\Users\71589\AppData\Local\Temp\ipykernel_5156\1191907490.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method=('ffill'))
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# ...

# %%
df.Age_Group.unique()
# Out:
# array(['Adults (35-64)', 'Young Adults (25-34)', 'Youth (<25)', nan],
#       dtype=object)

# %%
def age(Customer_Age):
    if Customer_Age<25:
        return 'Youth (<25)'
    if Customer_Age<35:
        return 'Young Adults (25-34)'
    return 'Adults (35-64)'

# %%
df.Age_Group.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84    False
# 85    False
# 86    False
# 87    False
# 88    False
# Name: Age_Group, Length: 89, dtype: bool

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
df = df.drop_duplicates (subset=['Sales_Order #'], keep = 'last')

# %%
df
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  \
# 0          261695 2021-12-01   1.0  December  2021            39
# 1          261695 2021-12-01   1.0  December  2021            44
# 2          261697 2021-12-02   2.0  December  2021            37
# 3          261698 2021-12-02   2.0  December  2021            31
# 4          261699 2021-12-03   3.0  December  2021            37
# ..            ...        ...   ...       ...   ...           ...
# 84         261778 2021-12-22  22.0  December  2021            41
# 85         261779 2021-12-23  23.0  December  2021            30
# 86         261780 2021-12-23  23.0  December  2021            31
# 87         261781 2021-12-23  23.0  December  2021            35
# 88         261782 2021-12-24  24.0  December  2021            38
#
#                Age_Group Customer_Gender         Country             State  \
# 0         Adults (35-64)               F   United States        California
# ...

# %%
le= LabelEncoder()
le.fit(df.Age_Group)
df['Age_Group'] = le.fit_transform(df['Age_Group'])

# %%
df
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  Age_Group  \
# 0          261695 2021-12-01   1.0  December  2021            39          0
# 1          261695 2021-12-01   1.0  December  2021            44          0
# 2          261697 2021-12-02   2.0  December  2021            37          0
# 3          261698 2021-12-02   2.0  December  2021            31          1
# 4          261699 2021-12-03   3.0  December  2021            37          0
# ..            ...        ...   ...       ...   ...           ...        ...
# 84         261778 2021-12-22  22.0  December  2021            41          0
# 85         261779 2021-12-23  23.0  December  2021            30          1
# 86         261780 2021-12-23  23.0  December  2021            31          1
# 87         261781 2021-12-23  23.0  December  2021            35          0
# 88         261782 2021-12-24  24.0  December  2021            38          0
#
# ...

# %%
le.classes_
# Out:
# array(['Adults (35-64)', 'Young Adults (25-34)', 'Youth (<25)', nan],
#       dtype=object)

# %%
df['Age_Group'] = le.inverse_transform(df['Age_Group'])

# %%
df
# Out:
#     Sales_Order #       Date   Day     Month  Year  Customer_Age  Age_Group  \
# 0          261695 2021-12-01   1.0  December  2021            39          0
# 1          261695 2021-12-01   1.0  December  2021            44          0
# 2          261697 2021-12-02   2.0  December  2021            37          0
# 3          261698 2021-12-02   2.0  December  2021            31          1
# 4          261699 2021-12-03   3.0  December  2021            37          0
# ..            ...        ...   ...       ...   ...           ...        ...
# 84         261778 2021-12-22  22.0  December  2021            41          0
# 85         261779 2021-12-23  23.0  December  2021            30          1
# 86         261780 2021-12-23  23.0  December  2021            31          1
# 87         261781 2021-12-23  23.0  December  2021            35          0
# 88         261782 2021-12-24  24.0  December  2021            38          0
#
# ...

# %%
cat=df.columns[6:13]
cat
# Out:
# Index(['Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product_Description'],
#       dtype='object')

# %%
scaler = StandardScaler()
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
df
# Out:
#     Sales_Order #       Date       Day     Month  Year  Customer_Age  \
# 0       -1.683323 2021-12-01 -1.972340  December   0.0      0.596359
# 1       -1.683323 2021-12-01 -1.972340  December   0.0      1.217858
# 2       -1.605152 2021-12-02 -1.814982  December   0.0      0.347760
# 3       -1.566066 2021-12-02 -1.814982  December   0.0     -0.398038
# 4       -1.526980 2021-12-03 -1.657624  December   0.0      0.347760
# ..            ...        ...       ...       ...   ...           ...
# 84       1.560796 2021-12-22  1.332179  December   0.0      0.844959
# 85       1.599882 2021-12-23  1.489537  December   0.0     -0.522338
# 86       1.638968 2021-12-23  1.489537  December   0.0     -0.398038
# 87       1.678053 2021-12-23  1.489537  December   0.0      0.099160
# 88       1.717139 2021-12-24  1.646895  December   0.0      0.472060
#
#                Age_Group Customer_Gender         Country             State  \
# ...

# %%
scaler = StandardScaler()

numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
df_scaled = df.copy()  
df_scaled[numerical_columns] = scaler.fit_transform(df[numerical_columns])

df_scaled.head()
# Out:
#    Sales_Order #       Date       Day     Month  Year  Customer_Age  \
# 0      -1.683323 2021-12-01 -1.972340  December   0.0      0.596359
# 1      -1.683323 2021-12-01 -1.972340  December   0.0      1.217858
# 2      -1.605152 2021-12-02 -1.814982  December   0.0      0.347760
# 3      -1.566066 2021-12-02 -1.814982  December   0.0     -0.398038
# 4      -1.526980 2021-12-03 -1.657624  December   0.0      0.347760
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
#   Product_Category    Sub_Category        Product_Description  Order_Quantity  \
# ...

# %%
df.Cost.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5448\1020137078.py in ?()
# ----> 1 df.Cost.hist()
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Cost'
