# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\71589\Desktop\laptopData.csv") df.drop(columns=['Unnamed: 0'], inplace = True)
# Out:
#   Cell In[18], line 1
#     df = pd.read_csv(r"C:\Users\71589\Desktop\laptopData.csv") df.drop(columns=['Unnamed: 0'], inplace = True)
#                                                                ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.isnull()

# %%
df.isnull().mean()
# Out:
# Unnamed: 0          0.023024
# Company             0.023024
# TypeName            0.023024
# Inches              0.023024
# ScreenResolution    0.023024
# Cpu                 0.023024
# Ram                 0.023024
# Memory              0.023024
# Gpu                 0.023024
# OpSys               0.023024
# Weight              0.023024
# Price               0.023024
# dtype: float64

# %%
df.dropna()
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.fillna(method=('ffill'))
# Out:
# C:\Users\71589\AppData\Local\Temp\ipykernel_9020\1191907490.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method=('ffill'))
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# ...

# %%
df=df.fillna(method='ffill')
# Out:
# C:\Users\71589\AppData\Local\Temp\ipykernel_9020\1718901248.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='ffill')

# %%
df.ScreenResolution.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: ScreenResolution, Length: 1303, dtype: bool

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df = df.drop_duplicates (subset=['ScreenResolution'], keep = 'last')

# %%
df
# Out:
#       Unnamed: 0    Company            TypeName Inches  \
# 17          17.0      Apple           Ultrabook   15.4
# 20           NaN        NaN                 NaN    NaN
# 33          33.0       Dell           Ultrabook   13.3
# 34          34.0      Apple           Ultrabook   13.3
# 214        214.0     Huawei           Ultrabook     13
# 270        270.0      Apple           Ultrabook   13.3
# 323        323.0         HP            Notebook   15.6
# 411        411.0     Lenovo           Ultrabook     14
# 421        421.0      Chuwi            Notebook   12.3
# 670        670.0  Microsoft           Ultrabook   13.5
# 718        718.0   Mediacom            Notebook     14
# 762        762.0     Google           Ultrabook   12.3
# 763        763.0       Asus           Ultrabook   13.3
# 791        791.0       Vero            Notebook     14
# 816        816.0      Razer           Ultrabook   12.5
# 826        826.0       Asus  2 in 1 Convertible   13.3
# ...

# %%
df
# Out:
#       Unnamed: 0    Company            TypeName Inches  \
# 17          17.0      Apple           Ultrabook   15.4
# 20           NaN        NaN                 NaN    NaN
# 33          33.0       Dell           Ultrabook   13.3
# 34          34.0      Apple           Ultrabook   13.3
# 214        214.0     Huawei           Ultrabook     13
# 270        270.0      Apple           Ultrabook   13.3
# 323        323.0         HP            Notebook   15.6
# 411        411.0     Lenovo           Ultrabook     14
# 421        421.0      Chuwi            Notebook   12.3
# 670        670.0  Microsoft           Ultrabook   13.5
# 718        718.0   Mediacom            Notebook     14
# 762        762.0     Google           Ultrabook   12.3
# 763        763.0       Asus           Ultrabook   13.3
# 791        791.0       Vero            Notebook     14
# 816        816.0      Razer           Ultrabook   12.5
# 826        826.0       Asus  2 in 1 Convertible   13.3
# ...

# %%
le= LabelEncoder()
le.fit(df.Company)
df['Company'] = le.fit_transform(df['Company'])

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
scaler = StandardScaler()

numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
df_scaled = df.copy()  
df_scaled[numerical_columns] = scaler.fit_transform(df[numerical_columns])

df_scaled.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0   -1.734245   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   -1.731588   Apple  Ultrabook   13.3                            1440x900
# 2   -1.728931      HP   Notebook   15.6                   Full HD 1920x1080
# 3   -1.726274   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   -1.723617   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight     Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  0.306099
# ...

# %%
apple_df = df[df['Company'] == 'Apple']
scaled_apple_df = apple_df.copy()  
scaled_apple_df[numerical_columns] = scaler.fit_transform(apple_df[numerical_columns])

# %%
scaled_apple_df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0   -0.650110   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   -0.647937   Apple  Ultrabook   13.3                            1440x900
# 3   -0.643592   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   -0.641420   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 6   -0.637075   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
#
#                     Cpu   Ram               Memory  \
# 0  Intel Core i5 2.3GHz   8GB            128GB SSD
# 1  Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3  Intel Core i7 2.7GHz  16GB            512GB SSD
# 4  Intel Core i5 3.1GHz   8GB            256GB SSD
# 6  Intel Core i7 2.2GHz  16GB  256GB Flash Storage
#
#                             Gpu     OpSys  Weight     Price
# 0  Intel Iris Plus Graphics 640     macOS  1.37kg -0.409621
# 1        Intel HD Graphics 6000     macOS  1.34kg -1.213779
# ...

# %%
dell_df = df[df['Company'] == 'Dell']
scaled_dell_df = dell_df.copy()  
scaled_dell_df[numerical_columns] = scaler.fit_transform(dell_df[numerical_columns])
scaled_dell_df.head()
# Out:
#     Unnamed: 0 Company            TypeName Inches  \
# 13   -1.680619    Dell            Notebook   15.6
# 16   -1.672575    Dell            Notebook   15.6
# 19   -1.664530    Dell           Ultrabook   13.3
# 23   -1.653805    Dell  2 in 1 Convertible   13.3
# 25   -1.648442    Dell            Notebook   15.6
#
#                              ScreenResolution                         Cpu  \
# 13                          Full HD 1920x1080    Intel Core i3 6006U 2GHz
# 16                          Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 19  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
# 23            Full HD / Touchscreen 1920x1080  Intel Core i5 8250U 1.6GHz
# 25                                   1366x768    Intel Core i3 6006U 2GHz
#
#     Ram     Memory                     Gpu       OpSys  Weight     Price
# 13  4GB  256GB SSD      AMD Radeon R5 M430  Windows 10   2.2kg -1.015612
# ...

# %%
df.Company.unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', nan, 'Chuwi',
#        'MSI', 'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
def split_memory(memory):
    if isinstance(memory, str):
        parts = memory.split(' ', 1)
        if len(parts) == 2:
            return parts
    # Handle cases where memory is not a string (e.g., float)
    return ['Unknown', 'Unknown']

# Apply the function to the 'Memory' column
df['Memory_split'] = df['Memory'].apply(split_memory)
df['Memory_split'].head()
# Out:
# 0              [128GB, SSD]
# 1    [128GB, Flash Storage]
# 2              [256GB, SSD]
# 3              [512GB, SSD]
# 4              [256GB, SSD]
# Name: Memory_split, dtype: object

# %%
def split_ScreenResolution(ScreenResolution):
    if isinstance(ScreenResolution, str):
        parts = ScreenResolution.split(' ', 1)
        if len(parts) == 2:
            return parts
    # Handle cases where memory is not a string (e.g., float)
    return ['Unknown', 'Unknown']

# Apply the function to the 'Memory' column
df['ScreenResolution_split'] = df['ScreenResolution'].apply(split_ScreenResolution)
df['ScreenResolution_split'].head()
# Out:
# 0    [IPS, Panel Retina Display 2560x1600]
# 1                       [Unknown, Unknown]
# 2                     [Full, HD 1920x1080]
# 3    [IPS, Panel Retina Display 2880x1800]
# 4    [IPS, Panel Retina Display 2560x1600]
# Name: ScreenResolution_split, dtype: object

# %%
df['TypeName'].str.split('.')
# Out:
# 0                [Ultrabook]
# 1                [Ultrabook]
# 2                 [Notebook]
# 3                [Ultrabook]
# 4                [Ultrabook]
#                 ...
# 1298    [2 in 1 Convertible]
# 1299    [2 in 1 Convertible]
# 1300              [Notebook]
# 1301              [Notebook]
# 1302              [Notebook]
# Name: TypeName, Length: 1303, dtype: object

# %%
split_TypeName = df['TypeName'].str.split(' ')
split_TypeName.head()
# Out:
# 0    [Ultrabook]
# 1    [Ultrabook]
# 2     [Notebook]
# 3    [Ultrabook]
# 4    [Ultrabook]
# Name: TypeName, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.Price.hist()
# Out:
# <Axes: >

# %%
corr = df.select_dtypes(include=np.number).corr()
dataplot = sb.heatmap(corr,  annot=True, cmap="YlGnBu") # cmap="YlGnBu",
plt.show()

# %%
# pairplot with hue sex
sb.pairplot(df, hue="smoker")
# to show
plt.show()
