# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv(r"../../dataset/laptopData.csv")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42)
df_train
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 1158      1158.0  Lenovo            Notebook   15.6
# 904        904.0  Lenovo            Notebook   15.6
# 439        439.0    Asus            Notebook   15.6
# 581        581.0    Dell            Notebook   15.6
# 676        676.0    Asus           Ultrabook     14
# ...          ...     ...                 ...    ...
# 1095      1095.0    Acer            Notebook   15.6
# 1130      1130.0      HP            Notebook   15.6
# 1294      1294.0      HP            Notebook   15.6
# 860        860.0  Lenovo            Notebook   15.6
# 1126      1126.0  Lenovo  2 in 1 Convertible   10.1
#
#                      ScreenResolution                          Cpu  Ram  \
# 1158                Full HD 1920x1080   Intel Core i5 6200U 2.3GHz  8GB
# 904       IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz  8GB
# 439                 Full HD 1920x1080   Intel Core i5 7200U 2.5GHz  4GB
# 581                          1366x768   Intel Core i5 7300U 2.6GHz  8GB
# 676                 Full HD 1920x1080   Intel Core i5 7200U 2.5GHz  8GB
# ...                               ...                          ...  ...
# 1095                Full HD 1920x1080   Intel Core i5 7200U 2.5GHz  8GB
# 1130                         1366x768   Intel Core i7 7500U 2.7GHz  8GB
# 1294                Full HD 1920x1080    AMD A9-Series 9410 2.9GHz  6GB
# 860       IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz  8GB
# 1126  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
#
#                     Memory                      Gpu       OpSys  Weight  \
# 1158          1.0TB Hybrid       AMD Radeon R5 M330  Windows 10   2.5kg
# 904              512GB SSD    Intel HD Graphics 620  Windows 10  1.95kg
# 439              256GB SSD    Intel HD Graphics 620       Linux     2kg
# 581              500GB HDD    Intel HD Graphics 620  Windows 10   1.9kg
# 676              256GB SSD    Intel HD Graphics 620  Windows 10   1.1kg
# ...                    ...                      ...         ...     ...
# 1095  256GB SSD +  1TB HDD  Nvidia GeForce GTX 950M  Windows 10   2.4kg
# 1130               2TB HDD    Intel HD Graphics 620  Windows 10  2.04kg
# 1294          1.0TB Hybrid       AMD Radeon R7 M440  Windows 10  2.04kg
# 860                1TB HDD    Intel HD Graphics 620  Windows 10   2.3kg
# 1126    64GB Flash Storage    Intel HD Graphics 400  Windows 10  0.69kg
#
#             Price
# 1158   42010.7472
# 904   104588.1072
# 439    29783.5200
# 581    53733.9456
# 676    60472.8000
# ...           ...
# 1095   42570.7200
# 1130   33513.1200
# 1294   29303.4672
# 860    45323.1648
# 1126   25521.1200
#
# [912 rows x 12 columns]

# %%
df_train.isnull().sum()
# Out:
# Unnamed: 0          23
# Company             23
# TypeName            23
# Inches              23
# ScreenResolution    23
# Cpu                 23
# Ram                 23
# Memory              23
# Gpu                 23
# OpSys               23
# Weight              23
# Price               23
# dtype: int64

# %%
df_train = df_train.drop(columns="Unnamed: 0")

# %%
df_test = df_test.drop(columns="Unnamed: 0")

# %%
df_train.isnull().sum()
# Out:
# Company             23
# TypeName            23
# Inches              23
# ScreenResolution    23
# Cpu                 23
# Ram                 23
# Memory              23
# Gpu                 23
# OpSys               23
# Weight              23
# Price               23
# dtype: int64

# %%
df_train = df_train.replace("?", np.nan)

# %%
df_test = df_test.replace("?", np.nan)

# %%
df_train = df_train.dropna()

# %%
df_test = df_test.dropna()

# %%
df_train['Ram'] = df_train['Ram'].str.replace("GB", "")
df_train['Ram'] = pd.to_numeric(df_train['Ram'], errors='coerce')

# %%
df_test['Ram'] = df_test['Ram'].str.replace("GB", "")
df_test['Ram'] = pd.to_numeric(df_test['Ram'], errors='coerce')

# %%
df_train['Weight'] = df_train['Weight'].str.replace("kg", "")
df_train['Weight'] = pd.to_numeric(df_train['Weight'], errors='coerce')

# %%
df_test['Weight'] = df_test['Weight'].str.replace("kg", "")
df_test['Weight'] = pd.to_numeric(df_test['Weight'], errors='coerce')

# %%
def split_memory_column(dataframe, column_name):
    # Split the column into two new columns
    dataframe[['Memory', 'Memory_Type']] = dataframe[column_name].str.split(' ', n=1, expand=True)
    return dataframe

# %%
df_train = split_memory_column(df_train, 'Memory')
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram Memory                      Gpu  \
# 1158   Intel Core i5 6200U 2.3GHz    8  1.0TB       AMD Radeon R5 M330
# 904    Intel Core i5 7200U 2.5GHz    8  512GB    Intel HD Graphics 620
# 439    Intel Core i5 7200U 2.5GHz    4  256GB    Intel HD Graphics 620
# 581    Intel Core i5 7300U 2.6GHz    8  500GB    Intel HD Graphics 620
# 676    Intel Core i5 7200U 2.5GHz    8  256GB    Intel HD Graphics 620
# ...                           ...  ...    ...                      ...
# 1095   Intel Core i5 7200U 2.5GHz    8  256GB  Nvidia GeForce GTX 950M
# 1130   Intel Core i7 7500U 2.7GHz    8    2TB    Intel HD Graphics 620
# 1294    AMD A9-Series 9410 2.9GHz    6  1.0TB       AMD Radeon R7 M440
# 860    Intel Core i5 7200U 2.5GHz    8    1TB    Intel HD Graphics 620
# 1126  Intel Atom x5-Z8550 1.44GHz    4   64GB    Intel HD Graphics 400
#
#            OpSys  Weight        Price     Memory_Type
# 1158  Windows 10    2.50   42010.7472          Hybrid
# 904   Windows 10    1.95  104588.1072             SSD
# 439        Linux    2.00   29783.5200             SSD
# 581   Windows 10    1.90   53733.9456             HDD
# 676   Windows 10    1.10   60472.8000             SSD
# ...          ...     ...          ...             ...
# 1095  Windows 10    2.40   42570.7200  SSD +  1TB HDD
# 1130  Windows 10    2.04   33513.1200             HDD
# 1294  Windows 10    2.04   29303.4672          Hybrid
# 860   Windows 10    2.30   45323.1648             HDD
# 1126  Windows 10    0.69   25521.1200   Flash Storage
#
# [888 rows x 12 columns]

# %%
def split_memory_unit(dataframe, column_name):
    dataframe['Memory_Capacity'] = dataframe[column_name].str.extract('(\d+)')
    dataframe['Memory_Unit'] = dataframe[column_name].str.extract('([A-Za-z]+)')
    return dataframe
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\71519\AppData\Local\Temp\ipykernel_17400\2639091969.py:2: SyntaxWarning: invalid escape sequence '\d'
#   dataframe['Memory_Capacity'] = dataframe[column_name].str.extract('(\d+)')

# %%
df_train = split_memory_unit(df_train, 'Memory')
df_train['Memory_Capacity'] = pd.to_numeric(df_train['Memory_Capacity'], errors='coerce')
df_train = df_train.drop(columns="Memory")
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                      Gpu       OpSys  \
# 1158   Intel Core i5 6200U 2.3GHz    8       AMD Radeon R5 M330  Windows 10
# 904    Intel Core i5 7200U 2.5GHz    8    Intel HD Graphics 620  Windows 10
# 439    Intel Core i5 7200U 2.5GHz    4    Intel HD Graphics 620       Linux
# 581    Intel Core i5 7300U 2.6GHz    8    Intel HD Graphics 620  Windows 10
# 676    Intel Core i5 7200U 2.5GHz    8    Intel HD Graphics 620  Windows 10
# ...                           ...  ...                      ...         ...
# 1095   Intel Core i5 7200U 2.5GHz    8  Nvidia GeForce GTX 950M  Windows 10
# 1130   Intel Core i7 7500U 2.7GHz    8    Intel HD Graphics 620  Windows 10
# 1294    AMD A9-Series 9410 2.9GHz    6       AMD Radeon R7 M440  Windows 10
# 860    Intel Core i5 7200U 2.5GHz    8    Intel HD Graphics 620  Windows 10
# 1126  Intel Atom x5-Z8550 1.44GHz    4    Intel HD Graphics 400  Windows 10
#
#       Weight        Price     Memory_Type  Memory_Capacity Memory_Unit
# 1158    2.50   42010.7472          Hybrid                1          TB
# 904     1.95  104588.1072             SSD              512          GB
# 439     2.00   29783.5200             SSD              256          GB
# 581     1.90   53733.9456             HDD              500          GB
# 676     1.10   60472.8000             SSD              256          GB
# ...      ...          ...             ...              ...         ...
# 1095    2.40   42570.7200  SSD +  1TB HDD              256          GB
# 1130    2.04   33513.1200             HDD                2          TB
# 1294    2.04   29303.4672          Hybrid                1          TB
# 860     2.30   45323.1648             HDD                1          TB
# 1126    0.69   25521.1200   Flash Storage               64          GB
#
# [888 rows x 13 columns]

# %%
df_test = split_memory_column(df_test, 'Memory')
df_test = split_memory_unit(df_test, 'Memory')
df_test['Memory_Capacity'] = pd.to_numeric(df_test['Memory_Capacity'], errors='coerce')
df_test = df_test.drop(columns="Memory")
df_test
# Out:
#       Company            TypeName Inches  \
# 479   Toshiba            Notebook   13.3
# 1022       HP            Notebook   13.3
# 298    Lenovo            Notebook   15.6
# 1265   Lenovo            Notebook   15.6
# 582        HP            Notebook   13.3
# ...       ...                 ...    ...
# 672    Lenovo  2 in 1 Convertible   13.3
# 506      Asus            Notebook   15.6
# 668   Toshiba            Notebook   15.6
# 778     Razer              Gaming     14
# 723      Dell              Gaming   17.3
#
#                                ScreenResolution                          Cpu  \
# 479                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1022                IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 298                           Full HD 1920x1080  AMD A10-Series 9600P 2.4GHz
# 1265                IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 582                           Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# ...                                         ...                          ...
# 672   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i5 7200U 2.5GHz
# 506                           Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 668                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 778                           Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 723                       4K Ultra HD 3840x2160  Intel Core i7 7700HQ 2.8GHz
#
#       Ram                      Gpu       OpSys  Weight       Price  \
# 479     8    Intel HD Graphics 620  Windows 10    1.05   89084.160
# 1022    8    Intel HD Graphics 620  Windows 10    1.11   61218.720
# 298     6        AMD Radeon R5 430  Windows 10    2.40   26586.720
# 1265    8  Nvidia GeForce GTX 960M  Windows 10    2.60   47898.720
# 582     4    Intel HD Graphics 620  Windows 10    1.49   38308.320
# ...   ...                      ...         ...     ...         ...
# 672     8    Intel HD Graphics 620  Windows 10    1.30   55091.520
# 506     8    Intel HD Graphics 620  Windows 10    2.00   65214.720
# 668     8    Intel HD Graphics 620  Windows 10    2.00   67026.240
# 778    16  Nvidia GeForce GTX 1060  Windows 10    1.95  154458.720
# 723    32  Nvidia GeForce GTX 1070  Windows 10    4.36  194972.832
#
#          Memory_Type  Memory_Capacity Memory_Unit
# 479              SSD              256          GB
# 1022             SSD              256          GB
# 298              HDD                1          TB
# 1265             HDD                1          TB
# 582              SSD              128          GB
# ...              ...              ...         ...
# 672              SSD              256          GB
# 506   SSD +  1TB HDD              256          GB
# 668              SSD              256          GB
# 778              SSD              512          GB
# 723   SSD +  1TB HDD                1          TB
#
# [382 rows x 13 columns]

# %%
def categorize_resolution(dataframe, column_name):
    # Mapping of resolution to descriptive labels based on provided dataset
    resolution_dict = {
        '1366x768': 'HD',
        '1920x1080': 'Full HD',
        '2560x1440': 'Quad HD',
        '3200x1800': 'Quad HD+',
        '3840x2160': '4K Ultra HD'
    }

    # Directly map extracted resolutions to categories
    extracted_resolutions = dataframe[column_name].str.extract(r'(\d+x\d+)')[0]
    dataframe['Resolution_Category'] = extracted_resolutions.map(resolution_dict).fillna('Unknown')

    return dataframe

# %%
df_train = categorize_resolution(df_train, "ScreenResolution")
df_train[['Width', 'Height']] = df_train['ScreenResolution'].str.extract('(\d+)x(\d+)')
df_train['Width'] = pd.to_numeric(df_train['Width'], errors='coerce')
df_train['Height'] = pd.to_numeric(df_train['Height'], errors='coerce')
df_train = df_train.drop(columns="ScreenResolution")
df_train
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\71519\AppData\Local\Temp\ipykernel_17400\3492017563.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df_train[['Width', 'Height']] = df_train['ScreenResolution'].str.extract('(\d+)x(\d+)')
#      Company            TypeName Inches                          Cpu  Ram  \
# 1158  Lenovo            Notebook   15.6   Intel Core i5 6200U 2.3GHz    8
# 904   Lenovo            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 439     Asus            Notebook   15.6   Intel Core i5 7200U 2.5GHz    4
# 581     Dell            Notebook   15.6   Intel Core i5 7300U 2.6GHz    8
# 676     Asus           Ultrabook     14   Intel Core i5 7200U 2.5GHz    8
# ...      ...                 ...    ...                          ...  ...
# 1095    Acer            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 1130      HP            Notebook   15.6   Intel Core i7 7500U 2.7GHz    8
# 1294      HP            Notebook   15.6    AMD A9-Series 9410 2.9GHz    6
# 860   Lenovo            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 1126  Lenovo  2 in 1 Convertible   10.1  Intel Atom x5-Z8550 1.44GHz    4
#
#                           Gpu       OpSys  Weight        Price  \
# 1158       AMD Radeon R5 M330  Windows 10    2.50   42010.7472
# 904     Intel HD Graphics 620  Windows 10    1.95  104588.1072
# 439     Intel HD Graphics 620       Linux    2.00   29783.5200
# 581     Intel HD Graphics 620  Windows 10    1.90   53733.9456
# 676     Intel HD Graphics 620  Windows 10    1.10   60472.8000
# ...                       ...         ...     ...          ...
# 1095  Nvidia GeForce GTX 950M  Windows 10    2.40   42570.7200
# 1130    Intel HD Graphics 620  Windows 10    2.04   33513.1200
# 1294       AMD Radeon R7 M440  Windows 10    2.04   29303.4672
# 860     Intel HD Graphics 620  Windows 10    2.30   45323.1648
# 1126    Intel HD Graphics 400  Windows 10    0.69   25521.1200
#
#          Memory_Type  Memory_Capacity Memory_Unit Resolution_Category  Width  \
# 1158          Hybrid                1          TB             Full HD   1920
# 904              SSD              512          GB             Full HD   1920
# 439              SSD              256          GB             Full HD   1920
# 581              HDD              500          GB                  HD   1366
# 676              SSD              256          GB             Full HD   1920
# ...              ...              ...         ...                 ...    ...
# 1095  SSD +  1TB HDD              256          GB             Full HD   1920
# 1130             HDD                2          TB                  HD   1366
# 1294          Hybrid                1          TB             Full HD   1920
# 860              HDD                1          TB             Full HD   1920
# 1126   Flash Storage               64          GB             Unknown   1920
#
#       Height
# 1158    1080
# 904     1080
# 439     1080
# 581      768
# 676     1080
# ...      ...
# 1095    1080
# 1130     768
# 1294    1080
# 860     1080
# 1126    1200
#
# [888 rows x 15 columns]

# %%
df_test = categorize_resolution(df_test, "ScreenResolution")
df_test[['Width', 'Height']] = df_test['ScreenResolution'].str.extract('(\d+)x(\d+)')
df_test['Width'] = pd.to_numeric(df_test['Width'], errors='coerce')
df_test['Height'] = pd.to_numeric(df_test['Height'], errors='coerce')
df_test = df_test.drop(columns="ScreenResolution")
df_test
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\71519\AppData\Local\Temp\ipykernel_17400\2267410873.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df_test[['Width', 'Height']] = df_test['ScreenResolution'].str.extract('(\d+)x(\d+)')
#       Company            TypeName Inches                          Cpu  Ram  \
# 479   Toshiba            Notebook   13.3   Intel Core i5 7200U 2.5GHz    8
# 1022       HP            Notebook   13.3   Intel Core i5 7200U 2.5GHz    8
# 298    Lenovo            Notebook   15.6  AMD A10-Series 9600P 2.4GHz    6
# 1265   Lenovo            Notebook   15.6  Intel Core i7 6700HQ 2.6GHz    8
# 582        HP            Notebook   13.3   Intel Core i3 7100U 2.4GHz    4
# ...       ...                 ...    ...                          ...  ...
# 672    Lenovo  2 in 1 Convertible   13.3   Intel Core i5 7200U 2.5GHz    8
# 506      Asus            Notebook   15.6   Intel Core i7 7500U 2.7GHz    8
# 668   Toshiba            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 778     Razer              Gaming     14  Intel Core i7 7700HQ 2.8GHz   16
# 723      Dell              Gaming   17.3  Intel Core i7 7700HQ 2.8GHz   32
#
#                           Gpu       OpSys  Weight       Price     Memory_Type  \
# 479     Intel HD Graphics 620  Windows 10    1.05   89084.160             SSD
# 1022    Intel HD Graphics 620  Windows 10    1.11   61218.720             SSD
# 298         AMD Radeon R5 430  Windows 10    2.40   26586.720             HDD
# 1265  Nvidia GeForce GTX 960M  Windows 10    2.60   47898.720             HDD
# 582     Intel HD Graphics 620  Windows 10    1.49   38308.320             SSD
# ...                       ...         ...     ...         ...             ...
# 672     Intel HD Graphics 620  Windows 10    1.30   55091.520             SSD
# 506     Intel HD Graphics 620  Windows 10    2.00   65214.720  SSD +  1TB HDD
# 668     Intel HD Graphics 620  Windows 10    2.00   67026.240             SSD
# 778   Nvidia GeForce GTX 1060  Windows 10    1.95  154458.720             SSD
# 723   Nvidia GeForce GTX 1070  Windows 10    4.36  194972.832  SSD +  1TB HDD
#
#       Memory_Capacity Memory_Unit Resolution_Category  Width  Height
# 479               256          GB             Full HD   1920    1080
# 1022              256          GB             Full HD   1920    1080
# 298                 1          TB             Full HD   1920    1080
# 1265                1          TB             Full HD   1920    1080
# 582               128          GB             Full HD   1920    1080
# ...               ...         ...                 ...    ...     ...
# 672               256          GB             Full HD   1920    1080
# 506               256          GB             Full HD   1920    1080
# 668               256          GB             Full HD   1920    1080
# 778               512          GB             Full HD   1920    1080
# 723                 1          TB         4K Ultra HD   3840    2160
#
# [382 rows x 15 columns]

# %%
def split_GPU_column(dataframe, column_name):
    # Split the column into two new columns based on the last space
    dataframe[['Gpu', 'GPU_Ghz']] = dataframe[column_name].str.rsplit(' ', n=1, expand=True)
    return dataframe

# %%
df_train = split_GPU_column(df_train, "Gpu")
# df_train['GPU_Ghz'] = df_train['GPU_Ghz'].str.replace(r'[^\d.]', '', regex=True)
# df_train['GPU_Ghz'] = pd.to_numeric(df_train['GPU_Ghz'], errors='coerce')
df_train
# Out:
#      Company            TypeName Inches                          Cpu  Ram  \
# 1158  Lenovo            Notebook   15.6   Intel Core i5 6200U 2.3GHz    8
# 904   Lenovo            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 439     Asus            Notebook   15.6   Intel Core i5 7200U 2.5GHz    4
# 581     Dell            Notebook   15.6   Intel Core i5 7300U 2.6GHz    8
# 676     Asus           Ultrabook     14   Intel Core i5 7200U 2.5GHz    8
# ...      ...                 ...    ...                          ...  ...
# 1095    Acer            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 1130      HP            Notebook   15.6   Intel Core i7 7500U 2.7GHz    8
# 1294      HP            Notebook   15.6    AMD A9-Series 9410 2.9GHz    6
# 860   Lenovo            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 1126  Lenovo  2 in 1 Convertible   10.1  Intel Atom x5-Z8550 1.44GHz    4
#
#                      Gpu       OpSys  Weight        Price     Memory_Type  \
# 1158       AMD Radeon R5  Windows 10    2.50   42010.7472          Hybrid
# 904    Intel HD Graphics  Windows 10    1.95  104588.1072             SSD
# 439    Intel HD Graphics       Linux    2.00   29783.5200             SSD
# 581    Intel HD Graphics  Windows 10    1.90   53733.9456             HDD
# 676    Intel HD Graphics  Windows 10    1.10   60472.8000             SSD
# ...                  ...         ...     ...          ...             ...
# 1095  Nvidia GeForce GTX  Windows 10    2.40   42570.7200  SSD +  1TB HDD
# 1130   Intel HD Graphics  Windows 10    2.04   33513.1200             HDD
# 1294       AMD Radeon R7  Windows 10    2.04   29303.4672          Hybrid
# 860    Intel HD Graphics  Windows 10    2.30   45323.1648             HDD
# 1126   Intel HD Graphics  Windows 10    0.69   25521.1200   Flash Storage
#
#       Memory_Capacity Memory_Unit Resolution_Category  Width  Height GPU_Ghz
# 1158                1          TB             Full HD   1920    1080    M330
# 904               512          GB             Full HD   1920    1080     620
# 439               256          GB             Full HD   1920    1080     620
# 581               500          GB                  HD   1366     768     620
# 676               256          GB             Full HD   1920    1080     620
# ...               ...         ...                 ...    ...     ...     ...
# 1095              256          GB             Full HD   1920    1080    950M
# 1130                2          TB                  HD   1366     768     620
# 1294                1          TB             Full HD   1920    1080    M440
# 860                 1          TB             Full HD   1920    1080     620
# 1126               64          GB             Unknown   1920    1200     400
#
# [888 rows x 16 columns]

# %%
df_test = split_GPU_column(df_test, "Gpu")
# df_test['GPU_Ghz'] = df_test['GPU_Ghz'].str.replace(r'[^\d.]', '', regex=True)
# df_test['GPU_Ghz'] = pd.to_numeric(df_test['GPU_Ghz'], errors='coerce')
df_test
# Out:
#       Company            TypeName Inches                          Cpu  Ram  \
# 479   Toshiba            Notebook   13.3   Intel Core i5 7200U 2.5GHz    8
# 1022       HP            Notebook   13.3   Intel Core i5 7200U 2.5GHz    8
# 298    Lenovo            Notebook   15.6  AMD A10-Series 9600P 2.4GHz    6
# 1265   Lenovo            Notebook   15.6  Intel Core i7 6700HQ 2.6GHz    8
# 582        HP            Notebook   13.3   Intel Core i3 7100U 2.4GHz    4
# ...       ...                 ...    ...                          ...  ...
# 672    Lenovo  2 in 1 Convertible   13.3   Intel Core i5 7200U 2.5GHz    8
# 506      Asus            Notebook   15.6   Intel Core i7 7500U 2.7GHz    8
# 668   Toshiba            Notebook   15.6   Intel Core i5 7200U 2.5GHz    8
# 778     Razer              Gaming     14  Intel Core i7 7700HQ 2.8GHz   16
# 723      Dell              Gaming   17.3  Intel Core i7 7700HQ 2.8GHz   32
#
#                      Gpu       OpSys  Weight       Price     Memory_Type  \
# 479    Intel HD Graphics  Windows 10    1.05   89084.160             SSD
# 1022   Intel HD Graphics  Windows 10    1.11   61218.720             SSD
# 298        AMD Radeon R5  Windows 10    2.40   26586.720             HDD
# 1265  Nvidia GeForce GTX  Windows 10    2.60   47898.720             HDD
# 582    Intel HD Graphics  Windows 10    1.49   38308.320             SSD
# ...                  ...         ...     ...         ...             ...
# 672    Intel HD Graphics  Windows 10    1.30   55091.520             SSD
# 506    Intel HD Graphics  Windows 10    2.00   65214.720  SSD +  1TB HDD
# 668    Intel HD Graphics  Windows 10    2.00   67026.240             SSD
# 778   Nvidia GeForce GTX  Windows 10    1.95  154458.720             SSD
# 723   Nvidia GeForce GTX  Windows 10    4.36  194972.832  SSD +  1TB HDD
#
#       Memory_Capacity Memory_Unit Resolution_Category  Width  Height GPU_Ghz
# 479               256          GB             Full HD   1920    1080     620
# 1022              256          GB             Full HD   1920    1080     620
# 298                 1          TB             Full HD   1920    1080     430
# 1265                1          TB             Full HD   1920    1080    960M
# 582               128          GB             Full HD   1920    1080     620
# ...               ...         ...                 ...    ...     ...     ...
# 672               256          GB             Full HD   1920    1080     620
# 506               256          GB             Full HD   1920    1080     620
# 668               256          GB             Full HD   1920    1080     620
# 778               512          GB             Full HD   1920    1080    1060
# 723                 1          TB         4K Ultra HD   3840    2160    1070
#
# [382 rows x 16 columns]

# %%
def split_CPU_column(dataframe, column_name):
    # Split the column into two new columns based on the last space
    dataframe[['Cpu', 'Cpu_Ghz']] = dataframe[column_name].str.rsplit(' ', n=1, expand=True)
    return dataframe

# %%
df_train = split_CPU_column(df_train, "Cpu")
df_train
# Out:
#      Company            TypeName Inches                  Cpu  Ram  \
# 1158  Lenovo            Notebook   15.6  Intel Core i5 6200U    8
# 904   Lenovo            Notebook   15.6  Intel Core i5 7200U    8
# 439     Asus            Notebook   15.6  Intel Core i5 7200U    4
# 581     Dell            Notebook   15.6  Intel Core i5 7300U    8
# 676     Asus           Ultrabook     14  Intel Core i5 7200U    8
# ...      ...                 ...    ...                  ...  ...
# 1095    Acer            Notebook   15.6  Intel Core i5 7200U    8
# 1130      HP            Notebook   15.6  Intel Core i7 7500U    8
# 1294      HP            Notebook   15.6   AMD A9-Series 9410    6
# 860   Lenovo            Notebook   15.6  Intel Core i5 7200U    8
# 1126  Lenovo  2 in 1 Convertible   10.1  Intel Atom x5-Z8550    4
#
#                      Gpu       OpSys  Weight        Price     Memory_Type  \
# 1158       AMD Radeon R5  Windows 10    2.50   42010.7472          Hybrid
# 904    Intel HD Graphics  Windows 10    1.95  104588.1072             SSD
# 439    Intel HD Graphics       Linux    2.00   29783.5200             SSD
# 581    Intel HD Graphics  Windows 10    1.90   53733.9456             HDD
# 676    Intel HD Graphics  Windows 10    1.10   60472.8000             SSD
# ...                  ...         ...     ...          ...             ...
# 1095  Nvidia GeForce GTX  Windows 10    2.40   42570.7200  SSD +  1TB HDD
# 1130   Intel HD Graphics  Windows 10    2.04   33513.1200             HDD
# 1294       AMD Radeon R7  Windows 10    2.04   29303.4672          Hybrid
# 860    Intel HD Graphics  Windows 10    2.30   45323.1648             HDD
# 1126   Intel HD Graphics  Windows 10    0.69   25521.1200   Flash Storage
#
#       Memory_Capacity Memory_Unit Resolution_Category  Width  Height GPU_Ghz  \
# 1158                1          TB             Full HD   1920    1080    M330
# 904               512          GB             Full HD   1920    1080     620
# 439               256          GB             Full HD   1920    1080     620
# 581               500          GB                  HD   1366     768     620
# 676               256          GB             Full HD   1920    1080     620
# ...               ...         ...                 ...    ...     ...     ...
# 1095              256          GB             Full HD   1920    1080    950M
# 1130                2          TB                  HD   1366     768     620
# 1294                1          TB             Full HD   1920    1080    M440
# 860                 1          TB             Full HD   1920    1080     620
# 1126               64          GB             Unknown   1920    1200     400
#
#       Cpu_Ghz
# 1158   2.3GHz
# 904    2.5GHz
# 439    2.5GHz
# 581    2.6GHz
# 676    2.5GHz
# ...       ...
# 1095   2.5GHz
# 1130   2.7GHz
# 1294   2.9GHz
# 860    2.5GHz
# 1126  1.44GHz
#
# [888 rows x 17 columns]

# %%
df_test = split_CPU_column(df_test, "Cpu")
df_test
# Out:
#       Company            TypeName Inches                   Cpu  Ram  \
# 479   Toshiba            Notebook   13.3   Intel Core i5 7200U    8
# 1022       HP            Notebook   13.3   Intel Core i5 7200U    8
# 298    Lenovo            Notebook   15.6  AMD A10-Series 9600P    6
# 1265   Lenovo            Notebook   15.6  Intel Core i7 6700HQ    8
# 582        HP            Notebook   13.3   Intel Core i3 7100U    4
# ...       ...                 ...    ...                   ...  ...
# 672    Lenovo  2 in 1 Convertible   13.3   Intel Core i5 7200U    8
# 506      Asus            Notebook   15.6   Intel Core i7 7500U    8
# 668   Toshiba            Notebook   15.6   Intel Core i5 7200U    8
# 778     Razer              Gaming     14  Intel Core i7 7700HQ   16
# 723      Dell              Gaming   17.3  Intel Core i7 7700HQ   32
#
#                      Gpu       OpSys  Weight       Price     Memory_Type  \
# 479    Intel HD Graphics  Windows 10    1.05   89084.160             SSD
# 1022   Intel HD Graphics  Windows 10    1.11   61218.720             SSD
# 298        AMD Radeon R5  Windows 10    2.40   26586.720             HDD
# 1265  Nvidia GeForce GTX  Windows 10    2.60   47898.720             HDD
# 582    Intel HD Graphics  Windows 10    1.49   38308.320             SSD
# ...                  ...         ...     ...         ...             ...
# 672    Intel HD Graphics  Windows 10    1.30   55091.520             SSD
# 506    Intel HD Graphics  Windows 10    2.00   65214.720  SSD +  1TB HDD
# 668    Intel HD Graphics  Windows 10    2.00   67026.240             SSD
# 778   Nvidia GeForce GTX  Windows 10    1.95  154458.720             SSD
# 723   Nvidia GeForce GTX  Windows 10    4.36  194972.832  SSD +  1TB HDD
#
#       Memory_Capacity Memory_Unit Resolution_Category  Width  Height GPU_Ghz  \
# 479               256          GB             Full HD   1920    1080     620
# 1022              256          GB             Full HD   1920    1080     620
# 298                 1          TB             Full HD   1920    1080     430
# 1265                1          TB             Full HD   1920    1080    960M
# 582               128          GB             Full HD   1920    1080     620
# ...               ...         ...                 ...    ...     ...     ...
# 672               256          GB             Full HD   1920    1080     620
# 506               256          GB             Full HD   1920    1080     620
# 668               256          GB             Full HD   1920    1080     620
# 778               512          GB             Full HD   1920    1080    1060
# 723                 1          TB         4K Ultra HD   3840    2160    1070
#
#      Cpu_Ghz
# 479   2.5GHz
# 1022  2.5GHz
# 298   2.4GHz
# 1265  2.6GHz
# 582   2.4GHz
# ...      ...
# 672   2.5GHz
# 506   2.7GHz
# 668   2.5GHz
# 778   2.8GHz
# 723   2.8GHz
#
# [382 rows x 17 columns]

# %%
df_train['Cpu_Ghz'] = df_train['Cpu_Ghz'].str.replace("GHz", "")
df_train['Cpu_Ghz'] = pd.to_numeric(df_train['Cpu_Ghz'], errors='coerce')

# %%
df_test['Cpu_Ghz'] = df_test['Cpu_Ghz'].str.replace("GHz", "")
df_test['Cpu_Ghz'] = pd.to_numeric(df_test['Cpu_Ghz'], errors='coerce')

# %%
# def split_CPU1_column(dataframe, column_name):
#     # Split the column into two new columns based on the last space
#     dataframe[['Cpu', 'Cpu_model']] = dataframe[column_name].str.rsplit(' ', n=1, expand=True)
#     return dataframe

# %%
# df_test = split_CPU1_column(df_test, "Cpu")
# df_test

# %%
# df_train = split_CPU1_column(df_train, "Cpu")
# df_train

# %%
# from sklearn.preprocessing import MinMaxScaler
# # Scaling for columns except the target (Price) column
# numeric_columns = ['Inches', 'Ram', 'Weight', 'Memory_Capacity' , 'Cpu_Ghz']
# for col in numeric_columns:
#     df_train[col] = pd.to_numeric(df_train[col], errors='coerce')

# scaler = MinMaxScaler()
# df_train[numeric_columns] = scaler.fit_transform(df_train[numeric_columns])

# %%
# # Scaling (transform only) for test df except the target (Price) column
# numeric_columns = ['Inches', 'Ram', 'Weight', 'Memory_Capacity' , 'Cpu_Ghz']
# for col in numeric_columns:
#     df_test[col] = pd.to_numeric(df_test[col], errors='coerce')

# df_test[numeric_columns] = scaler.transform(df_test[numeric_columns])

# %%
le = LabelEncoder()
classes = dict()
cat = df_test.select_dtypes(exclude = np.number).columns
for i in cat:
    df_test[i] = le.fit_transform(df_test[i])
    classes[i] = le.classes_
df_test
# Out:
#       Company  TypeName  Inches  Cpu  Ram  Gpu  OpSys  Weight       Price  \
# 479        15         3       5   31    8   10      4    1.05   89084.160
# 1022        6         3       5   31    8   10      4    1.11   61218.720
# 298         9         3       9    0    6    6      4    2.40   26586.720
# 1265        9         3       9   40    8   19      4    2.60   47898.720
# 582         6         3       5   24    4   10      4    1.49   38308.320
# ...       ...       ...     ...  ...  ...  ...    ...     ...         ...
# 672         9         0       5   31    8   10      4    1.30   55091.520
# 506         2         3       9   43    8   10      4    2.00   65214.720
# 668        15         3       9   31    8   10      4    2.00   67026.240
# 778        13         1       8   46   16   19      4    1.95  154458.720
# 723         3         1      10   46   32   19      4    4.36  194972.832
#
#       Memory_Type  Memory_Capacity  Memory_Unit  Resolution_Category  Width  \
# 479             4              256            0                    1   1920
# 1022            4              256            0                    1   1920
# 298             2                1            1                    1   1920
# 1265            2                1            1                    1   1920
# 582             4              128            0                    1   1920
# ...           ...              ...          ...                  ...    ...
# 672             4              256            0                    1   1920
# 506             6              256            0                    1   1920
# 668             4              256            0                    1   1920
# 778             4              512            0                    1   1920
# 723             6                1            1                    0   3840
#
#       Height  GPU_Ghz  Cpu_Ghz
# 479     1080       20      2.5
# 1022    1080       20      2.5
# 298     1080        9      2.4
# 1265    1080       30      2.6
# 582     1080       20      2.4
# ...      ...      ...      ...
# 672     1080       20      2.5
# 506     1080       20      2.7
# 668     1080       20      2.5
# 778     1080        3      2.8
# 723     2160        4      2.8
#
# [382 rows x 17 columns]

# %%
category = df_train.select_dtypes(exclude = np.number).columns
le = LabelEncoder()
classes = dict()
for i in category:
    df_train[i] = le.fit_transform(df_train[i])
    classes[i] = le.classes_
df_train
# Out:
#       Company  TypeName  Inches  Cpu  Ram  Gpu  OpSys  Weight        Price  \
# 1158       10         3      14   45    8    6      5    2.50   42010.7472
# 904        10         3      14   49    8   13      5    1.95  104588.1072
# 439         2         3      14   49    4   13      2    2.00   29783.5200
# 581         4         3      14   51    8   13      5    1.90   53733.9456
# 676         2         4      10   49    8   13      5    1.10   60472.8000
# ...       ...       ...     ...  ...  ...  ...    ...     ...          ...
# 1095        0         3      14   49    8   23      5    2.40   42570.7200
# 1130        7         3      14   65    8   13      5    2.04   33513.1200
# 1294        7         3      14    8    6    7      5    2.04   29303.4672
# 860        10         3      14   49    8   13      5    2.30   45323.1648
# 1126       10         0       0   21    4   13      5    0.69   25521.1200
#
#       Memory_Type  Memory_Capacity  Memory_Unit  Resolution_Category  Width  \
# 1158            3                1            1                    1   1920
# 904             4              512            0                    1   1920
# 439             4              256            0                    1   1920
# 581             1              500            0                    2   1366
# 676             4              256            0                    1   1920
# ...           ...              ...          ...                  ...    ...
# 1095            5              256            0                    1   1920
# 1130            1                2            1                    2   1366
# 1294            3                1            1                    1   1920
# 860             1                1            1                    1   1920
# 1126            0               64            0                    5   1920
#
#       Height  GPU_Ghz  Cpu_Ghz
# 1158    1080       54     2.30
# 904     1080       27     2.50
# 439     1080       27     2.50
# 581      768       27     2.60
# 676     1080       27     2.50
# ...      ...      ...      ...
# 1095    1080       38     2.50
# 1130     768       27     2.70
# 1294    1080       59     2.90
# 860     1080       27     2.50
# 1126    1200       10     1.44
#
# [888 rows x 17 columns]

# %%
df_train = df_train.dropna()
df_test = df_test.dropna()

# %%
x_train = df_train.drop(columns = 'Price').values
x_train
# Out:
# array([[  10.  ,    3.  ,   14.  , ..., 1080.  ,   54.  ,    2.3 ],
#        [  10.  ,    3.  ,   14.  , ..., 1080.  ,   27.  ,    2.5 ],
#        [   2.  ,    3.  ,   14.  , ..., 1080.  ,   27.  ,    2.5 ],
#        ...,
#        [   7.  ,    3.  ,   14.  , ..., 1080.  ,   59.  ,    2.9 ],
#        [  10.  ,    3.  ,   14.  , ..., 1080.  ,   27.  ,    2.5 ],
#        [  10.  ,    0.  ,    0.  , ..., 1200.  ,   10.  ,    1.44]])

# %%
y_train = df_train['Price'].values
y_train
# Out:
# array([ 42010.7472, 104588.1072,  29783.52  ,  53733.9456,  60472.8   ,
#         30310.992 ,  33513.12  ,  61751.52  , 137995.2   ,  31381.92  ,
#        130269.6   , 175770.72  ,  65480.5872,  38841.12  ,  46833.12  ,
#         13053.0672,  47365.92  ,  58607.4672,  78588.    ,  13445.7408,
#         53226.72  ,  63882.72  ,  70809.12  ,  67132.8   ,  15824.16  ,
#         47898.72  ,  26533.44  , 135195.336 ,  73473.12  ,  53226.72  ,
#         23176.8   ,  12201.12  ,  36496.8   ,  98514.72  ,  29463.84  ,
#         34578.72  , 124568.64  ,  14652.    ,  37570.392 ,  25840.8   ,
#         62231.04  ,  15877.44  ,  21312.    ,  38308.32  , 149130.72  ,
#         79653.6   , 138474.72  ,  31914.72  ,  74538.72  ,  36763.2   ,
#         67260.672 ,  87219.36  , 102777.12  ,  71928.    ,  45074.88  ,
#         41505.12  ,  60153.12  ,  31381.92  ,  10810.512 ,  52054.56  ,
#         48618.    ,  60952.32  ,  63936.    ,  69210.72  ,  41025.0672,
#         25521.12  ,  99047.52  ,  46886.4   ,  61272.    ,  26267.04  ,
#         42890.4   ,  26053.92  ,  81465.12  ,  22857.12  ,  60153.12  ,
#         85194.72  ,  84715.2   ,  83063.52  ,  63882.72  ,  74485.44  ,
#         53173.44  ,  44701.92  ,  70489.44  ,  38378.6496,  36709.92  ,
#         47952.    ,  44701.92  , 126273.6   ,  61005.6   ,  26581.392 ,
#         44968.32  ,  64948.32  ,  72940.32  ,  19367.8128,  95850.72  ,
#         48964.32  , 119916.2304, 111834.72  , 104695.2   ,  38378.6496,
#         32639.8608,  41292.    ,  57808.8   ,  52161.12  ,  47898.72  ,
#         34433.2656,  69210.72  ,  23922.72  ,  24988.32  ,  53226.72  ,
#         34093.872 ,  42570.72  ,  58554.72  , 168045.12  ,   9270.72  ,
#        121584.96  ,  74005.92  , 111834.72  ,  15877.44  ,  34045.3872,
#         25521.12  ,  27899.0064,  31914.1872,  63882.72  ,  62284.32  ,
#         24988.32  , 119427.12  ,  53280.    ,  42570.72  ,  33513.12  ,
#         29303.4672,  45323.1648,  25521.12  ])

# %%
df_train = df_train.dropna()
df_test = df_test.dropna()

# %%
x_test = df_test.drop(columns = 'Price').values

# %%
y_test = df_test['Price'].values

# %%
reg = LinearRegression() 
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
y_pred[:10]
# Out:
# array([ 64385.95248868,  61679.66410183,  35978.90909092,  62025.68205315,
#         46580.58108834,  37274.31779541,  74956.9610243 ,  26160.25923647,
#        130003.62546192,  38132.28688075])

# %%
y_test[:10]
# Out:
# array([ 89084.16,  61218.72,  26586.72,  47898.72,  38308.32,  24455.52,
#         63456.48,  18594.72, 101178.72,  38681.28])

# %%
np.mean(np.square(y_test - y_pred))
# Out:
# 485990692.9410919

# %%
np.mean(np.absolute(y_test - y_pred))
# Out:
# 14768.393100520996

# %%
y_mean = np.mean(y_test)
TSS = np.sum(np.square(y_test - y_mean))
RSS = np.sum(np.square(y_test - y_pred))
1- RSS/ TSS
# Out:
# 0.6850853535458628

# %%
r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred)
# Out:
# (0.6850853535458628, 485990692.9410919, 14768.393100520996)

# %%
from sklearn.linear_model import Ridge

ridge_reg = Ridge(alpha=1.0)
ridge_reg.fit(x_train, y_train)
y_pred_ridge = ridge_reg.predict(x_test)

# %%
r2_score(y_test, y_pred_ridge), mean_squared_error(y_test, y_pred_ridge), mean_absolute_error(y_test, y_pred_ridge)
# Out:
# (0.6850052599112422, 486114297.10313296, 14763.153708379323)

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

lasso = Lasso(alpha=0.1)  # You might need to adjust alpha based on your specific dataset
lasso.fit(X_train_scaled, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred = lasso.predict(X_test_scaled)

# %%
r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred)
# Out:
# (0.6850797086359554, 485999404.4243727, 14768.312385765372)
