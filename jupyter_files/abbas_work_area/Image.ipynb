# %% [markdown]
# # Image Processing

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# Save image in set directory
# Read RGB image
img = cv2.imread('images/moon.bmp') 
 
# Output img with window name as 'image'
img1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(img1, cmap = 'grey')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 6
#       3 img = cv2.imread('images/moon.bmp')
#       5 # Output img with window name as 'image'
# ----> 6 img1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#       7 plt.imshow(img1, cmap = 'grey')
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
img2 = img1.T
plt.imshow(img2, cmap = 'grey')

# %%
img1[:10]
# Out:
# array([[[ 68,  73,   0],
#         [146, 148,  47],
#         [137, 138,  19],
#         ...,
#         [116, 101,   6],
#         [ 71,  61,  12],
#         [ 33,  24,   9]],
#
#        [[117, 125,   4],
#         [137, 141,  20],
#         [145, 146,  19],
#         ...,
#         [112,  95,  23],
#         [ 78,  68,  19],
#         [ 48,  43,  13]],
#
#        [[146, 155,   0],
#         [135, 140,   0],
#         [166, 166,  36],
#         ...,
#         [ 99,  80,  21],
#         [ 71,  63,  14],
#         [ 50,  51,   7]],
#
#        ...,
#
#        [[139, 121,   0],
#         [136, 114,  13],
#         [139, 111,  38],
#         ...,
#         [165, 133,  12],
#         [155, 136,   0],
#         [139, 129,   0]],
#
#        [[135, 125,   0],
#         [136, 116,   3],
#         [150, 116,  27],
#         ...,
#         [ 94,  85,  20],
#         [108, 105,  24],
#         [113, 114,  21]],
#
#        [[161, 143,  17],
#         [164, 141,  27],
#         [168, 135,  40],
#         ...,
#         [ 65,  55,   0],
#         [ 52,  48,   0],
#         [ 58,  57,   0]]], dtype=uint8)

# %%
img2[:10]
# Out:
# array([[[ 68.00000001,  73.00000001,   0.        ],
#         [146.00000001, 148.00000001,  47.        ],
#         [137.00000001, 138.00000001,  19.        ],
#         ...,
#         [116.00000001, 101.00000001,   6.        ],
#         [ 71.00000001,  61.00000001,  12.        ],
#         [ 33.        ,  24.        ,   9.        ]],
#
#        [[117.00000001, 125.00000001,   4.        ],
#         [137.00000001, 141.00000001,  20.        ],
#         [145.00000001, 146.00000001,  19.        ],
#         ...,
#         [112.00000001,  95.00000001,  23.        ],
#         [ 78.00000001,  68.00000001,  19.        ],
#         [ 48.        ,  43.        ,  13.        ]],
#
#        [[146.00000001, 155.00000002,   0.        ],
#         [135.00000001, 140.00000001,   0.        ],
#         [166.00000002, 166.00000002,  36.        ],
#         ...,
#         [ 99.00000001,  80.00000001,  21.        ],
#         [ 71.00000001,  63.00000001,  14.        ],
#         [ 50.00000001,  51.00000001,   7.        ]],
#
#        ...,
#
#        [[139.00000001, 121.00000001,   0.        ],
#         [136.00000001, 114.00000001,  13.        ],
#         [139.00000001, 111.00000001,  38.        ],
#         ...,
#         [165.00000002, 133.00000001,  12.        ],
#         [155.00000002, 136.00000001,   0.        ],
#         [139.00000001, 129.00000001,   0.        ]],
#
#        [[135.00000001, 125.00000001,   0.        ],
#         [136.00000001, 116.00000001,   3.        ],
#         [150.00000002, 116.00000001,  27.        ],
#         ...,
#         [ 94.00000001,  85.00000001,  20.        ],
#         [108.00000001, 105.00000001,  24.        ],
#         [113.00000001, 114.00000001,  21.        ]],
#
#        [[161.00000002, 143.00000001,  17.        ],
#         [164.00000002, 141.00000001,  27.        ],
#         [168.00000002, 135.00000001,  40.        ],
#         ...,
#         [ 65.00000001,  55.00000001,   0.        ],
#         [ 52.00000001,  48.        ,   0.        ],
#         [ 58.00000001,  57.00000001,   0.        ]]])

# %%
plt.imshow(np.zeros((20, 20, 3))+255)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [255.0..255.0].

# %%
from skimage.exposure import histogram
from skimage import io
