# %%
from numpy import random
import math
import matplotlib.pyplot as plt

# %%
binomials = random.binomial(n=6, p=0.1, size=1000)
plt.hist(binomials, density=True, bins=4, color='lightgreen')
plt.ylabel('probability', color='red')
plt.xlabel('number of success', color='red')
# Out:
# Text(0.5, 0, 'number of success')
