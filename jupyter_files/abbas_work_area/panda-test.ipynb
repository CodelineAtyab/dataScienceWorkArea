# %% [markdown]
# # Pandas 🐼

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv(r"../../dataset/mobile-data.csv")

# %%
df
# Out:
#       Unnamed: 0                                  Name  Rating  Spec_score  \
# 0              0                 Samsung Galaxy F14 5G    4.65          68
# 1              1                    Samsung Galaxy A11    4.20          63
# 2              2                    Samsung Galaxy A13    4.30          75
# 3              3                    Samsung Galaxy F23    4.10          73
# 4              4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
# ...          ...                                   ...     ...         ...
# 1365        1365                               TCL 40R    4.05          75
# 1366        1366                 TCL 50 XL NxtPaper 5G    4.10          80
# 1367        1367                 TCL 50 XE NxtPaper 5G    4.00          80
# 1368        1368                    TCL 40 NxtPaper 5G    4.50          79
# 1369        1369                           TCL Trifold    4.65          93
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1370 non-null   int64
#  1   Name               1370 non-null   object
#  2   Rating             1370 non-null   float64
#  3   Spec_score         1370 non-null   int64
#  4   No_of_sim          1370 non-null   object
#  5   Ram                1370 non-null   object
#  6   Battery            1370 non-null   object
#  7   Display            1370 non-null   object
#  8   Camera             1370 non-null   object
#  9   External_Memory    1370 non-null   object
#  10  Android_version    927 non-null    object
#  11  Price              1370 non-null   object
#  12  company            1370 non-null   object
#  13  Inbuilt_memory     1351 non-null   object
#  14  fast_charging      1281 non-null   object
#  15  Screen_resolution  1368 non-null   object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0       Rating   Spec_score
# count  1370.000000  1370.000000  1370.000000
# mean    684.500000     4.374416    80.234307
# std     395.629246     0.230176     8.373922
# min       0.000000     3.750000    42.000000
# 25%     342.250000     4.150000    75.000000
# 50%     684.500000     4.400000    82.000000
# 75%    1026.750000     4.550000    86.000000
# max    1369.000000     4.750000    98.000000

# %%
df.Rating.describe()
# Out:
# count    1370.000000
# mean        4.374416
# std         0.230176
# min         3.750000
# 25%         4.150000
# 50%         4.400000
# 75%         4.550000
# max         4.750000
# Name: Rating, dtype: float64

# %%
df[['Rating', 'Name', 'Price']].describe()
# Out:
#             Rating
# count  1370.000000
# mean      4.374416
# std       0.230176
# min       3.750000
# 25%       4.150000
# 50%       4.400000
# 75%       4.550000
# max       4.750000

# %%
df.Rating.hist()
# Out:
# <Axes: >

# %%
df.boxplot("Rating")
Q0 = df['Rating'].quantile(0)
Q1 = df['Rating'].quantile(0.25)
Q2 = df['Rating'].quantile(0.5)
Q3 = df['Rating'].quantile(0.75)
Q4 = df['Rating'].quantile(1)
plt.text(1.1, Q0, 'Q0: {:.2f}'.format(Q0), color='grey')
plt.text(1.1, Q1, 'Q1: {:.2f}'.format(Q1), color='blue')
plt.text(1.1, Q2, 'Q2 (Median): {:.2f}'.format(Q2), color='green')
plt.text(1.1, Q3, 'Q3: {:.2f}'.format(Q3), color='red')
plt.text(1.1, Q4, 'Q4: {:.2f}'.format(Q4), color='orange')
# Out:
# Text(1.1, 4.75, 'Q4: 4.75')

# %%
values = df['company'].value_counts()
values.plot.bar()
# Out:
# <Axes: xlabel='company'>

# %%
df.dropna()
# Out:
#       Unnamed: 0                                  Name  Rating  Spec_score  \
# 0              0                 Samsung Galaxy F14 5G    4.65          68
# 1              1                    Samsung Galaxy A11    4.20          63
# 2              2                    Samsung Galaxy A13    4.30          75
# 4              4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
# 5              5                 Samsung Galaxy M13 5G    4.40          75
# ...          ...                                   ...     ...         ...
# 1365        1365                               TCL 40R    4.05          75
# 1366        1366                 TCL 50 XL NxtPaper 5G    4.10          80
# 1367        1367                 TCL 50 XE NxtPaper 5G    4.00          80
# 1368        1368                    TCL 40 NxtPaper 5G    4.50          79
# 1369        1369                           TCL Trifold    4.65          93
#
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0       Rating   Spec_score
# count  1370.000000  1370.000000  1370.000000
# mean    684.500000     4.374416    80.234307
# std     395.629246     0.230176     8.373922
# min       0.000000     3.750000    42.000000
# 25%     342.250000     4.150000    75.000000
# 50%     684.500000     4.400000    82.000000
# 75%    1026.750000     4.550000    86.000000
# max    1369.000000     4.750000    98.000000

# %%
corr = df.select_dtypes(include=np.number).corr()
corr
# Out:
#             Unnamed: 0    Rating  Spec_score
# Unnamed: 0    1.000000  0.026233   -0.044236
# Rating        0.026233  1.000000    0.056510
# Spec_score   -0.044236  0.056510    1.000000

# %%
import seaborn as sb
dataplot = sb.heatmap(corr, annot=True) 
plt.show()

# %%
sb.pairplot(df, hue="company")

# %%
samsung_ph = df[df['company'] == 'Samsung'].value_counts()
Hauwei_ph = df[df['company'] == 'TCL'].value_counts()

# %%
categories = ['Samsung', 'Hauwei']
counts = [samsung_ph.sum(), Hauwei_ph.sum()]

plt.bar(categories, counts)
# Out:
# <BarContainer object of 2 artists>

# %%
import geopandas as gpd

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

oman = world[world.name == 'Oman']

oman.plot()

plt.title('Geographical Boundaries of Oman')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()
# Out:
# C:\Users\71519\AppData\Local\Temp\ipykernel_2876\2840395496.py:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
df['Price'] = pd.to_numeric(df['Price'].astype(str).str.replace(',', ''), errors='coerce')

# Calculate the mean price for Samsung
companies = df['company'].unique()
mean_prices = {}
for company in companies:
    mean_prices[company] = df[df['company'] == company]['Price'].mean()

company_names = list(mean_prices.keys())
mean_price_values = list(mean_prices.values())
plt.figure(figsize=(25,15))
plt.bar(company_names, mean_price_values)

plt.xlabel('Company', fontsize=16)
plt.ylabel('Mean Price', fontsize=16)
plt.title('Mean Prices', fontsize=25)

plt.show()

# %%
category = df.select_dtypes(exclude = np.number).columns
category
# Out:
# Index(['Name', 'No_of_sim', 'Ram', 'Battery', 'Display', 'Camera',
#        'External_Memory', 'Android_version', 'company', 'Inbuilt_memory',
#        'fast_charging', 'Screen_resolution', 'Processor', 'Processor_name'],
#       dtype='object')

# %%
df1 = df.copy()
classes = dict()
le = LabelEncoder()
for col in category:
    df1[col]= le.fit_transform(df1[col])
    classes[col] = le.classes_
df3 = df1.copy()
df1
# Out:
#       Unnamed: 0  Name  Rating  Spec_score  No_of_sim  Ram  Battery  Display  \
# 0              0   860    4.65          68          1   10       86       43
# 1              1   805    4.20          63          3    6       20       28
# 2              2   807    4.30          75          3   10       62       43
# 3              3   867    4.10          73          3   10       85       28
# 4              4   794    4.10          69          3   10       62       34
# ...          ...   ...     ...         ...        ...  ...      ...      ...
# 1365        1365   978    4.05          75          1   10       62       43
# 1366        1366   985    4.10          80          3   14       62       60
# 1367        1367   983    4.00          80          1   12       62       43
# 1368        1368   969    4.50          79          1   12       62       43
# 1369        1369   990    4.65          93          2    2       44        0
#
# ...

# %%
X = df1.drop(columns = ['Price', 'Unnamed: 0']).values
X
# Out:
# array([[860.  ,   4.65,  68.  , ..., 111.  ,  12.  ,  67.  ],
#        [805.  ,   4.2 ,  63.  , ..., 122.  ,   2.  , 134.  ],
#        [807.  ,   4.3 ,  75.  , ...,  26.  ,   4.  , 134.  ],
#        ...,
#        [983.  ,   4.  ,  80.  , ..., 129.  ,  11.  ,  24.  ],
#        [969.  ,   4.5 ,  79.  , ..., 129.  ,  11.  ,  23.  ],
#        [990.  ,   4.65,  93.  , ..., 100.  ,  11.  , 237.  ]])

# %%
y = df1['Price'].values
y
# Out:
# array([  9999,   9990,  11999, ...,  23990,  22499, 119990], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_test.shape
# Out:
# (411, 16)

# %%
reg = LinearRegression() 
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([50114.99615255, 28773.93340828, 63583.99010577, 41399.14223541,
#        23008.05198394, 18117.89947421, 48691.12627653, 15557.32870788,
#        43343.0540723 , 15831.18907966])

# %%
y_test[:10]
# Out:
# array([28999, 30999, 72999, 27990, 11990, 39990, 56990,  8199, 59999,
#        10999], dtype=int64)

# %%
np.mean(np.square(y_test - y_pred))
# Out:
# 231874577.39265648

# %%
np.mean(np.absolute(y_test - y_pred))
# Out:
# 10955.391999548108

# %%
min(y), max(y)
# Out:
# (6950, 214990)

# %%
y_mean = np.mean(y_test)
TSS = np.sum(np.square(y_test - y_mean))
RSS = np.sum(np.square(y_test - y_pred))
1- RSS/ TSS
# Out:
# 0.7329357727894311

# %%
r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred)
# Out:
# (0.737029378338262, 228320364.73541808, 10763.972171147643)

# %%
df3 = df.copy()
classes = dict()
le = LabelEncoder()
for col in category:
    df3[col]= le.fit_transform(df3[col])
    classes[col] = le.classes_

# %%
df1
# Out:
#       Unnamed: 0  Name  Rating  Spec_score  No_of_sim  Ram  Battery  Display  \
# 0              0   860    4.65          68          1   10       86       43
# 1              1   805    4.20          63          3    6       20       28
# 2              2   807    4.30          75          3   10       62       43
# 3              3   867    4.10          73          3   10       85       28
# 4              4   794    4.10          69          3   10       62       34
# ...          ...   ...     ...         ...        ...  ...      ...      ...
# 1365        1365   978    4.05          75          1   10       62       43
# 1366        1366   985    4.10          80          3   14       62       60
# 1367        1367   983    4.00          80          1   12       62       43
# 1368        1368   969    4.50          79          1   12       62       43
# 1369        1369   990    4.65          93          2    2       44        0
#
# ...

# %%
X = df3.drop(columns = ['Price', 'Unnamed: 0'], ).values
X
# Out:
# array([[860.  ,   4.65,  68.  , ..., 111.  ,  12.  ,  67.  ],
#        [805.  ,   4.2 ,  63.  , ..., 122.  ,   2.  , 134.  ],
#        [807.  ,   4.3 ,  75.  , ...,  26.  ,   4.  , 134.  ],
#        ...,
#        [983.  ,   4.  ,  80.  , ..., 129.  ,  11.  ,  24.  ],
#        [969.  ,   4.5 ,  79.  , ..., 129.  ,  11.  ,  23.  ],
#        [990.  ,   4.65,  93.  , ..., 100.  ,  11.  , 237.  ]])

# %%
y = df3['Price'].values
y
# Out:
# array([  9999,   9990,  11999, ...,  23990,  22499, 119990], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_test.shape
# Out:
# (411, 16)

# %%
reg = LinearRegression() 
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
y_pred[:10]
# Out:
# array([50114.99615255, 28773.93340828, 63583.99010577, 41399.14223541,
#        23008.05198394, 18117.89947421, 48691.12627653, 15557.32870788,
#        43343.0540723 , 15831.18907966])

# %%
y_test[:10]
# Out:
# array([28999, 30999, 72999, 27990, 11990, 39990, 56990,  8199, 59999,
#        10999], dtype=int64)

# %%
np.mean(np.square(y_test - y_pred))
# Out:
# 231874577.39265648

# %%
np.mean(np.absolute(y_test - y_pred))
# Out:
# 10955.391999548108

# %%
min(y), max(y)
# Out:
# (6950, 214990)

# %%
y_mean = np.mean(y_test)
TSS = np.sum(np.square(y_test - y_mean))
RSS = np.sum(np.square(y_test - y_pred))
1- RSS/ TSS
# Out:
# 0.7329357727894311
