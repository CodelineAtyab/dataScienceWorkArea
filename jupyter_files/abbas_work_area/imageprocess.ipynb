# %%
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../../dataset/fruits_detailfeature.jpg")
plt.imshow(img)

# %%
img1 = img.copy()
img1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img
# Out:
# array([[[  0,  73,  68],
#         [ 47, 148, 146],
#         [ 19, 138, 137],
#         ...,
#         [  6, 101, 116],
#         [ 12,  61,  71],
#         [  9,  24,  33]],
#
#        [[  4, 125, 117],
#         [ 20, 141, 137],
#         [ 19, 146, 145],
#         ...,
#         [ 23,  95, 112],
#         [ 19,  68,  78],
#         [ 13,  43,  48]],
#
#        [[  0, 155, 146],
#         [  0, 140, 135],
#         [ 36, 166, 166],
#         ...,
#         [ 21,  80,  99],
#         [ 14,  63,  71],
#         [  7,  51,  50]],
#
#        ...,
#
#        [[ 86, 171, 193],
#         [ 97, 176, 197],
#         [115, 184, 203],
#         ...,
#         [ 72,  87, 156],
#         [ 47,  60, 116],
#         [ 20,  35,  74]],
#
#        [[ 93, 177, 203],
#         [ 89, 172, 194],
#         [ 86, 168, 186],
#         ...,
#         [ 62,  78, 154],
#         [ 58,  76, 141],
#         [ 47,  68, 120]],
#
#        [[108, 184, 213],
#         [ 92, 176, 201],
#         [ 74, 162, 179],
# ...

# %%
img.shape
# Out:
# (686, 1200, 3)

# %%
img1.shape
# Out:
# (686, 1200, 3)

# %%
img1[:, :, 1:2]
# Out:
# array([[[ 73],
#         [148],
#         [138],
#         ...,
#         [101],
#         [ 61],
#         [ 24]],
#
#        [[125],
#         [141],
#         [146],
#         ...,
#         [ 95],
#         [ 68],
#         [ 43]],
#
#        [[155],
#         [140],
#         [166],
#         ...,
#         [ 80],
#         [ 63],
#         [ 51]],
#
#        ...,
#
#        [[171],
#         [176],
#         [184],
#         ...,
#         [ 87],
#         [ 60],
#         [ 35]],
#
#        [[177],
#         [172],
#         [168],
#         ...,
#         [ 78],
#         [ 76],
#         [ 68]],
#
#        [[184],
#         [176],
#         [162],
#         ...,
#         [ 70],
#         [ 77],
#         [ 82]]], dtype=uint8)

# %%
img3 = cv2.imread("../../dataset/moon.bmp")

# %%
img3[:10]
# Out:
# array([[[61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75],
#         ...,
#         [61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75]],
#
#        [[61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75],
#         ...,
#         [61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75]],
#
#        [[61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75],
#         ...,
#         [61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75]],
#
#        ...,
#
#        [[61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75],
#         ...,
#         [61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75]],
#
#        [[61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75],
#         ...,
#         [61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75]],
#
#        [[61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75],
#         ...,
#         [61, 69, 75],
#         [61, 69, 75],
#         [61, 69, 75]]], dtype=uint8)

# %%
img1 = (img+20)%255
plt.imshow(img1)

# %%
img2 = img3.T
img2
# Out:
# array([[[61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61],
#         ...,
#         [61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61],
#         [61, 61, 61, ..., 61, 61, 61]],
#
#        [[69, 69, 69, ..., 69, 69, 69],
#         [69, 69, 69, ..., 69, 69, 69],
#         [69, 69, 69, ..., 69, 69, 69],
#         ...,
#         [69, 69, 69, ..., 69, 69, 69],
#         [69, 69, 69, ..., 69, 69, 69],
#         [69, 69, 69, ..., 69, 69, 69]],
#
#        [[75, 75, 75, ..., 75, 75, 75],
#         [75, 75, 75, ..., 75, 75, 75],
#         [75, 75, 75, ..., 75, 75, 75],
#         ...,
#         [75, 75, 75, ..., 75, 75, 75],
#         [75, 75, 75, ..., 75, 75, 75],
#         [75, 75, 75, ..., 75, 75, 75]]], dtype=uint8)

# %%
plt.imshow(img1, cmap='grey')
