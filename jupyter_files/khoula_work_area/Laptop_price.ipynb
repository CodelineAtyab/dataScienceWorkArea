# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv("../../dataset/laptopData.csv")
df.drop(columns = ['Unnamed: 0'], inplace = True)
df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42)
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                Memory  \
# ...

# %% [markdown]
# ## Regression Without preprocessing

# %%
df_train = df_train.replace('?', np.nan)

# %%
df_test = df_test.replace('?', np.nan)

# %%
df_train.dropna(inplace = True)
df_test.dropna(inplace = True)

# %%
df_test
# Out:
#       Company            TypeName Inches  \
# 479   Toshiba            Notebook   13.3
# 1022       HP            Notebook   13.3
# 298    Lenovo            Notebook   15.6
# 1265   Lenovo            Notebook   15.6
# 582        HP            Notebook   13.3
# ...       ...                 ...    ...
# 672    Lenovo  2 in 1 Convertible   13.3
# 506      Asus            Notebook   15.6
# 668   Toshiba            Notebook   15.6
# 778     Razer              Gaming     14
# 723      Dell              Gaming   17.3
#
#                                ScreenResolution                          Cpu  \
# 479                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1022                IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 298                           Full HD 1920x1080  AMD A10-Series 9600P 2.4GHz
# 1265                IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 582                           Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 1158 to 1126
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           888 non-null    object
#  1   TypeName          888 non-null    object
#  2   Inches            888 non-null    object
#  3   ScreenResolution  888 non-null    object
#  4   Cpu               888 non-null    object
#  5   Ram               888 non-null    object
#  6   Memory            888 non-null    object
#  7   Gpu               888 non-null    object
#  8   OpSys             888 non-null    object
#  9   Weight            888 non-null    object
#  10  Price             888 non-null    float64
# dtypes: float64(1), object(10)
# memory usage: 83.2+ KB

# %%
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                Memory  \
# ...

# %%
categorical = df_train.select_dtypes(exclude = np.number).columns

# %%
df1_train = df_train.copy()
df1_test = df_train.copy()
classes = dict()
le = LabelEncoder()
for col in categorical:
    df1_train[col]= le.fit_transform(df1_train[col])
    df1_test[col]= le.transform(df1_test[col])
    classes[col] = le.classes_

# %%
X_train, y_train = df1_train.drop(columns = 'Price').values, df1_train['Price'].values
X_test, y_test = df1_test.drop(columns = 'Price').values, df1_test['Price'].values

# %%
reg = LinearRegression() # ols
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
print('R2 =', r2_score(y_test, y_pred))
# Out:
# R2 = 0.4992660541388573

# %% [markdown]
# ### No preprocessing (R2 = 0.4992660541388573)

# %% [markdown]
# # Preprocessing

# %%
df['Company'].value_counts()
# Out:
# Company
# Lenovo       290
# Dell         287
# HP           266
# Asus         156
# Acer         103
# MSI           53
# Toshiba       47
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# LG             3
# Huawei         2
# Fujitsu        2
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Extraction

# %%
# Import the regular expression module
import re

def extract_ram_size(ram_description):
    try:
        ram_size = int(ram_description.replace('GB', '').strip())
        return ram_size
    except ValueError:
        return None
def extract_ScreenResolution(screen_description):
    try:
        ScreenResolution = screen_description.split()[-1]
        return ScreenResolution
    except ValueError:
        return None

def extract_cpu(cpu):
    ghz_match = re.search(r'(\d+(?:\.\d+)?+)GHz', cpu)
    if ghz_match:
        return float(ghz_match.group(1))
    else:
        return None
def extract_cpu_com(cpu):
    cpu_company = cpu.split()[0]
    if cpu_company:
        return cpu_company
    else:
        return None
def extract_Memory_size(memory_txt):
    memory = 0
    memory_matchTB = re.search(r'(\d+(?:\.\d+)?+)TB', memory_txt)
    if memory_matchTB:
        memory =  int(float(memory_matchTB.group(1)) * 1024)
    memory_matchGB = re.search(r'(\d+(?:\.\d+)?+)GB', memory_txt)
    if memory_matchGB:
        memory= memory+ int(memory_matchGB.group(1))
    return memory
def extract_Memory_type(memory_txt):
    memory_txt = re.sub(r'\w*\d\w*', '', memory_txt).strip()
    memory_txt = re.sub(r'\.', '', memory_txt).strip()    
    return memory_txt
def extract_Touchscreen(screen):
    if screen.includes('Touchscreen'):
        return 1
    else:
        return 0

# %%
# Extract RAM size in GB from "Ram" column
df_train['Ram'] = df_train['Ram'].apply(extract_ram_size)
df_test['Ram'] = df_test['Ram'].apply(extract_ram_size)

# %%
df_train['ScreenResolution'] = df_train['ScreenResolution'].apply(extract_ScreenResolution)
df_test['ScreenResolution'] = df_test['ScreenResolution'].apply(extract_ScreenResolution)

# %%
# Extract GHz value from "Cpu" column and create a new column "CpuGHz"
df_train['CpuGHz'] = df_train['Cpu'].apply(extract_cpu)
df_train['CpuCompany'] = df_train['Cpu'].apply(extract_cpu_com)
df_test['CpuGHz'] = df_test['Cpu'].apply(extract_cpu)
df_test['CpuCompany'] = df_test['Cpu'].apply(extract_cpu_com)

# %%
df_train.drop(columns=['Cpu'], inplace = True)
df_test.drop(columns=['Cpu'], inplace = True)
df_train
# Out:
#      Company            TypeName Inches ScreenResolution  Ram  \
# 1158  Lenovo            Notebook   15.6        1920x1080    8
# 904   Lenovo            Notebook   15.6        1920x1080    8
# 439     Asus            Notebook   15.6        1920x1080    4
# 581     Dell            Notebook   15.6         1366x768    8
# 676     Asus           Ultrabook     14        1920x1080    8
# ...      ...                 ...    ...              ...  ...
# 1095    Acer            Notebook   15.6        1920x1080    8
# 1130      HP            Notebook   15.6         1366x768    8
# 1294      HP            Notebook   15.6        1920x1080    6
# 860   Lenovo            Notebook   15.6        1920x1080    8
# 1126  Lenovo  2 in 1 Convertible   10.1        1920x1200    4
#
#                     Memory                      Gpu       OpSys  Weight  \
# 1158          1.0TB Hybrid       AMD Radeon R5 M330  Windows 10   2.5kg
# 904              512GB SSD    Intel HD Graphics 620  Windows 10  1.95kg
# ...

# %%
df_train['Memory'].values[:10]
# Out:
# array(['1.0TB Hybrid', '512GB SSD', '256GB SSD', '500GB HDD', '256GB SSD',
#        '128GB SSD', '1TB HDD', '64GB Flash Storage', '256GB SSD',
#        '1TB HDD'], dtype=object)

# %%
df_train['MemorySize'] = df_train['Memory'].apply(extract_Memory_size)
df_test['MemorySize'] = df_test['Memory'].apply(extract_Memory_size)

# %%
df_train['MemoryType'] = df_train['Memory'].apply(extract_Memory_type)
df_test['MemoryType'] = df_test['Memory'].apply(extract_Memory_type)

# %%
df_train.drop(columns=['Memory'], inplace = True)
df_test.drop(columns=['Memory'], inplace = True)

# %%
df_train["Weight"] = df_train["Weight"].str.replace("kg", "").astype(float)
df_test["Weight"] = df_test["Weight"].str.replace("kg", "").astype(float)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 1158 to 1126
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           888 non-null    object
#  1   TypeName          888 non-null    object
#  2   Inches            888 non-null    object
#  3   ScreenResolution  888 non-null    object
#  4   Ram               888 non-null    int64
#  5   Gpu               888 non-null    object
#  6   OpSys             888 non-null    object
#  7   Weight            888 non-null    float64
#  8   Price             888 non-null    float64
#  9   CpuGHz            888 non-null    float64
#  10  CpuCompany        888 non-null    object
#  11  MemorySize        888 non-null    int64
#  12  MemoryType        888 non-null    object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 97.1+ KB

# %% [markdown]
# ## Label Encoding

# %%
categorical = df_train.select_dtypes(exclude = np.number).columns

# %%
df2_train = df_train.copy()
df2_test = df_train.copy()
classes = dict()
le = LabelEncoder()
for col in categorical:
    df2_train[col]= le.fit_transform(df2_train[col])
    df2_test[col]= le.transform(df2_test[col])
    classes[col] = le.classes_

# %%
X_train, y_train = df2_train.drop(columns = 'Price').values, df2_train['Price'].values
X_test, y_test = df2_test.drop(columns = 'Price').values, df2_test['Price'].values

# %%
reg = LinearRegression() # ols
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
print('R2 train =', r2_score(y_train, reg.predict(X_train)))
print('R2 test=', r2_score(y_test, y_pred))
# Out:
# R2 train = 0.6901776171103353
# R2 test= 0.6901776171103353

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_pred = ridge.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
print('R2 train =', r2_score(y_train, ridge.predict(X_train)))
print('R2 test=', r2_score(y_test, y_pred))
# Out:
# R2 train = 0.690173594592884
# R2 test= 0.690173594592884

# %%
y_pred[:10]
# Out:
# array([50301.56506423, 62825.5640648 , 37426.11597035, 44479.00705605,
#        64972.08535195, 34507.02595054, 47141.38418968, 25282.32026587,
#        84148.08776123, 42028.64069064])

# %%
y_test[:10]
# Out:
# array([ 42010.7472, 104588.1072,  29783.52  ,  53733.9456,  60472.8   ,
#         30310.992 ,  33513.12  ,  61751.52  , 137995.2   ,  31381.92  ])

# %%
X_test[:10]
# Out:
# array([[1.000e+01, 3.000e+00, 1.400e+01, 3.000e+00, 8.000e+00, 1.500e+01,
#         5.000e+00, 2.500e+00, 2.300e+00, 1.000e+00, 1.024e+03, 3.000e+00],
#        [1.000e+01, 3.000e+00, 1.400e+01, 3.000e+00, 8.000e+00, 4.300e+01,
#         5.000e+00, 1.950e+00, 2.500e+00, 1.000e+00, 5.120e+02, 4.000e+00],
#        [2.000e+00, 3.000e+00, 1.400e+01, 3.000e+00, 4.000e+00, 4.300e+01,
#         2.000e+00, 2.000e+00, 2.500e+00, 1.000e+00, 2.560e+02, 4.000e+00],
#        [4.000e+00, 3.000e+00, 1.400e+01, 0.000e+00, 8.000e+00, 4.300e+01,
#         5.000e+00, 1.900e+00, 2.600e+00, 1.000e+00, 5.000e+02, 1.000e+00],
#        [2.000e+00, 4.000e+00, 1.000e+01, 3.000e+00, 8.000e+00, 4.300e+01,
#         5.000e+00, 1.100e+00, 2.500e+00, 1.000e+00, 2.560e+02, 4.000e+00],
#        [7.000e+00, 3.000e+00, 1.400e+01, 3.000e+00, 6.000e+00, 4.000e+00,
#         5.000e+00, 1.910e+00, 2.500e+00, 0.000e+00, 1.280e+02, 4.000e+00],
#        [0.000e+00, 3.000e+00, 1.600e+01, 2.000e+00, 8.000e+00, 5.900e+01,
# ...
