# %% [markdown]
# # Image Processing

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r'C:\Users\71524\OneDrive - omantel.om\Documents\Pandas\dataScienceWorkArea\jupyter_files\sara_work_area\images\horse.jpg')
#cv2.imshow('image',img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img
# Out:
# array([[[119, 110, 101],
#         [123, 114, 105],
#         [115, 106,  97],
#         ...,
#         [134, 125, 116],
#         [128, 119, 110],
#         [122, 113, 104]],
#
#        [[126, 117, 108],
#         [130, 121, 112],
#         [121, 112, 103],
#         ...,
#         [136, 127, 118],
#         [132, 123, 114],
#         [126, 117, 108]],
#
#        [[124, 115, 106],
#         [128, 119, 110],
#         [122, 113, 104],
#         ...,
#         [137, 128, 119],
#         [133, 124, 115],
#         [128, 119, 110]],
#
#        ...,
#
#        [[119, 109,  99],
#         [119, 109,  99],
#         [118, 108,  98],
#         ...,
#         [175, 112,  79],
#         [176, 116,  82],
#         [178, 119,  85]],
#
#        [[119, 109, 100],
#         [119, 109, 100],
#         [118, 108,  99],
#         ...,
#         [173, 114,  84],
#         [175, 116,  86],
#         [172, 113,  83]],
#
#        [[119, 109, 100],
#         [119, 109, 100],
#         [118, 108,  99],
# ...

# %%
img[:, :, 1:2]
# Out:
# array([[[110],
#         [114],
#         [106],
#         ...,
#         [125],
#         [119],
#         [113]],
#
#        [[117],
#         [121],
#         [112],
#         ...,
#         [127],
#         [123],
#         [117]],
#
#        [[115],
#         [119],
#         [113],
#         ...,
#         [128],
#         [124],
#         [119]],
#
#        ...,
#
#        [[109],
#         [109],
#         [108],
#         ...,
#         [112],
#         [116],
#         [119]],
#
#        [[109],
#         [109],
#         [108],
#         ...,
#         [114],
#         [116],
#         [113]],
#
#        [[109],
#         [109],
#         [108],
#         ...,
#         [114],
#         [116],
#         [113]]], dtype=uint8)

# %%
img2 = img + 30

# %%
plt.imshow(img2)

# %%
img[:10]
# Out:
# array([[[119, 110, 101],
#         [123, 114, 105],
#         [115, 106,  97],
#         ...,
#         [134, 125, 116],
#         [128, 119, 110],
#         [122, 113, 104]],
#
#        [[126, 117, 108],
#         [130, 121, 112],
#         [121, 112, 103],
#         ...,
#         [136, 127, 118],
#         [132, 123, 114],
#         [126, 117, 108]],
#
#        [[124, 115, 106],
#         [128, 119, 110],
#         [122, 113, 104],
#         ...,
#         [137, 128, 119],
#         [133, 124, 115],
#         [128, 119, 110]],
#
#        ...,
#
#        [[115, 103,  91],
#         [115, 103,  91],
#         [118, 106,  94],
#         ...,
#         [133, 124, 115],
#         [131, 122, 113],
#         [126, 117, 108]],
#
#        [[122, 109, 100],
#         [121, 108,  99],
#         [119, 106,  97],
#         ...,
#         [127, 118, 109],
#         [125, 118, 108],
#         [125, 118, 108]],
#
#        [[123, 110, 101],
#         [123, 110, 101],
#         [123, 110, 101],
# ...

# %%
img2[:10]
# Out:
# array([[[149, 140, 131],
#         [153, 144, 135],
#         [145, 136, 127],
#         ...,
#         [164, 155, 146],
#         [158, 149, 140],
#         [152, 143, 134]],
#
#        [[156, 147, 138],
#         [160, 151, 142],
#         [151, 142, 133],
#         ...,
#         [166, 157, 148],
#         [162, 153, 144],
#         [156, 147, 138]],
#
#        [[154, 145, 136],
#         [158, 149, 140],
#         [152, 143, 134],
#         ...,
#         [167, 158, 149],
#         [163, 154, 145],
#         [158, 149, 140]],
#
#        ...,
#
#        [[145, 133, 121],
#         [145, 133, 121],
#         [148, 136, 124],
#         ...,
#         [163, 154, 145],
#         [161, 152, 143],
#         [156, 147, 138]],
#
#        [[152, 139, 130],
#         [151, 138, 129],
#         [149, 136, 127],
#         ...,
#         [157, 148, 139],
#         [155, 148, 138],
#         [155, 148, 138]],
#
#        [[153, 140, 131],
#         [153, 140, 131],
#         [153, 140, 131],
# ...

# %%
img3 = (img+30)%255
plt.imshow(img3)

# %%
img_g = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_g, cmap = 'grey')

# %%
img_g.shape
# Out:
# (626, 1200)

# %%
img4 = img_g.T
plt.imshow(img4, cmap ='grey')
