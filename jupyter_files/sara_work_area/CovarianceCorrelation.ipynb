# %% [markdown]
# # Covariance & Correlation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("alzheimer.csv")
df
# Out:
#            Group M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0    Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1    Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2       Demented   M   75    12  NaN  23.0  0.5  1678  0.736  1.046
# 3       Demented   M   76    12  NaN  28.0  0.5  1738  0.713  1.010
# 4       Demented   M   80    12  NaN  22.0  0.5  1698  0.701  1.034
# ..           ...  ..  ...   ...  ...   ...  ...   ...    ...    ...
# 368     Demented   M   82    16  1.0  28.0  0.5  1693  0.694  1.037
# 369     Demented   M   86    16  1.0  26.0  0.5  1688  0.675  1.040
# 370  Nondemented   F   61    13  2.0  30.0  0.0  1319  0.801  1.331
# 371  Nondemented   F   63    13  2.0  30.0  0.0  1327  0.796  1.323
# 372  Nondemented   F   65    13  2.0  30.0  0.0  1333  0.801  1.317
#
# [373 rows x 10 columns]

# %%
df.describe()
# Out:
#               Age        EDUC         SES        MMSE         CDR  \
# count  373.000000  373.000000  354.000000  371.000000  373.000000
# mean    77.013405   14.597855    2.460452   27.342318    0.290885
# std      7.640957    2.876339    1.134005    3.683244    0.374557
# min     60.000000    6.000000    1.000000    4.000000    0.000000
# 25%     71.000000   12.000000    2.000000   27.000000    0.000000
# 50%     77.000000   15.000000    2.000000   29.000000    0.000000
# 75%     82.000000   16.000000    3.000000   30.000000    0.500000
# max     98.000000   23.000000    5.000000   30.000000    2.000000
#
#               eTIV        nWBV         ASF
# count   373.000000  373.000000  373.000000
# mean   1488.128686    0.729568    1.195461
# std     176.139286    0.037135    0.138092
# min    1106.000000    0.644000    0.876000
# 25%    1357.000000    0.700000    1.099000
# 50%    1470.000000    0.729000    1.194000
# 75%    1597.000000    0.756000    1.293000
# ...

# %%
df['Age'].mean()
# Out:
# 77.01340482573727

# %%
df["Age"].median()
# Out:
# 77.0

# %%
df[['Age']].boxplot()
plt.show()

# %%
df.hist()
plt.show()

# %%
#covariance metrix
df.select_dtypes(include=np.number).cov()
# Out:
#             Age        EDUC        SES       MMSE       CDR          eTIV  \
# Age   58.384228   -0.612874  -0.415086   1.569199 -0.075146     56.995582
# EDUC  -0.612874    8.273329  -2.372953   2.065659 -0.164966    130.213180
# SES   -0.415086   -2.372953   1.285967  -0.628231  0.032002    -52.137730
# MMSE   1.569199    2.065659  -0.628231  13.566285 -0.940424    -20.679063
# CDR   -0.075146   -0.164966   0.032002  -0.940424  0.140293      1.505477
# eTIV  56.995582  130.213180 -52.137730 -20.679063  1.505477  31025.047911
# nWBV  -0.147083   -0.001303   0.003866   0.046884 -0.004796     -1.374393
# ASF   -0.037001   -0.096024   0.039654   0.020142 -0.001518    -24.052858
#
#           nWBV        ASF
# Age  -0.147083  -0.037001
# EDUC -0.001303  -0.096024
# SES   0.003866   0.039654
# MMSE  0.046884   0.020142
# CDR  -0.004796  -0.001518
# eTIV -1.374393 -24.052858
# nWBV  0.001379   0.001095
# ASF   0.001095   0.019069

# %%
#correlation metrix
corr = df.select_dtypes(include=np.number).corr() 
corr
# Out:
#            Age      EDUC       SES      MMSE       CDR      eTIV      nWBV  \
# Age   1.000000 -0.027886 -0.046857  0.055612 -0.026257  0.042348 -0.518359
# EDUC -0.027886  1.000000 -0.722647  0.194884 -0.153121  0.257015 -0.012200
# SES  -0.046857 -0.722647  1.000000 -0.149219  0.076160 -0.261575  0.090095
# MMSE  0.055612  0.194884 -0.149219  1.000000 -0.686519 -0.032084  0.341912
# CDR  -0.026257 -0.153121  0.076160 -0.686519  1.000000  0.022819 -0.344819
# eTIV  0.042348  0.257015 -0.261575 -0.032084  0.022819  1.000000 -0.210122
# nWBV -0.518359 -0.012200  0.090095  0.341912 -0.344819 -0.210122  1.000000
# ASF  -0.035067 -0.241752  0.255576  0.040052 -0.029340 -0.988877  0.213476
#
#            ASF
# Age  -0.035067
# EDUC -0.241752
# SES   0.255576
# MMSE  0.040052
# CDR  -0.029340
# eTIV -0.988877
# nWBV  0.213476
# ASF   1.000000

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import seaborn as sb
dataplot = sb. heatmap(corr, annot=True)
# dataplot = sb. heatmap(corr, annot=True, cmap="YlGnBu")
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# Load a global dataset (e.g., Natural Earth shapefiles)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Filter the dataset to include only Oman
oman = world[world['name'] == 'Oman']
# Display the first few rows of the Oman GeoDataFrame
print(oman)
# Plot the map of Oman
oman.plot()
plt.title('Map of Oman')
plt.show()
# Out:
# C:\Users\71524\AppData\Local\Temp\ipykernel_15136\65648812.py:4: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       pop_est continent  name iso_a3  gdp_md_est  \
# 88  4974986.0      Asia  Oman    OMN       76331
#
#                                              geometry
# 88  MULTIPOLYGON (((55.20834 22.70833, 55.23449 23...

# %%
df.Age.hist()
plt.ylabel('Frequency')
plt.xlabel('Age')
plt.show()

# %%
df.Age.hist(color='purple', bins=10, figsize=(10, 5))
plt.show()

# %%
# Define age bins and labels
bins = [60, 70, 80, 90, 100]
labels = ['61-70', '71-80', '81-90', '91-100']

# Categorize ages into bins
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Count the occurrences of each age group
age_group_counts = df['Age Group'].value_counts().sort_index()

# Plot a pie chart
age_group_counts.plot.pie(
    autopct='%1.1f%%',  # Display the percentage value on the pie chart
    startangle=90,      # Start the pie chart at 90 degrees
    counterclock=False, # Draw the pie chart in a clockwise direction
    colors=plt.cm.Pastel2(range(len(labels)))  # Custom colors for the slices
)

plt.title('Age Group Distribution')
plt.show()

# %%
sb.pairplot(df, hue='EDUC')
plt.show()

# %%
sb.pairplot(df, hue='Group')
plt.show()

# %%
Nondemented = df[df['Group'] == 'Nondemented'].Age.mean()
Demented = df[df['Group'] == 'Demented'].Age.mean()
Converted = df[df['Group'] == 'Converted'].Age.mean()
plt.bar(['Nondemented', 'Demented','Converted'], [Nondemented, Demented,Converted])
plt.show()

# %%
plt.bar(df.Group.unique(), df.Group.value_counts())
plt.title('Group distribution')
plt.show()
