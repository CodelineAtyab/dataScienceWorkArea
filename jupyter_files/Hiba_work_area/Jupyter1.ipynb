# %%
list=[[random.random() for col in range(3)] for rown in range(100)]
print(list)
arr=np.random.rand(100,3)

#-----------------------
len(list)
len(list[0])
arr.shape
#print the secod elem of the first row
p=list[0][1]
#-----------pyth
for row in in list[1:4]:
    print(row[1:])
#--using np
arr=[1:4,1:]

arr.size()
arr.dtype()
arr.flatten()#one dim array []
arr.reshape(10,30)#10 elements in each elemnet 30 ele

#-----------------------------
np.sum(arr)#min,max,mean
#universal Functions
np.add(arr,2)
#-----
#arr LESS THAN 0.5 Filtering
#arr[arr LESS THAN 0.5] Masking
#----------
arr.sort() #each row sorted by row

# %% [markdown]
# PANDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\71591\\Desktop\\All_Children_Excel_Program_Attendance_20240525.csv")
df
# Out:
#                                           Title        Date Month Fiscal Year  \
# 0                   Me and You-kelele Storytime  07/01/2016   Jul       FY 17
# 1     MC Infants & Toddlers Bilingual Storytime  07/01/2016   Jul       FY 17
# 2                                  lego weekend  07/01/2016   Jul       FY 17
# 3                                 LEGO Playtime  07/01/2016   Jul       FY 17
# 4                                     LEGO Crew  07/01/2016   Jul       FY 17
# ...                                         ...         ...   ...         ...
# 1776                                 Act it Out  06/29/2017   Jun       FY 17
# 1777  MC Infants & Toddlers Bilingual Storytime  06/30/2017   Jun       FY 17
# 1778                     Lego Construction Crew  06/30/2017   Jun       FY 17
# 1779                    LEGO and DUPLO Playtime  06/30/2017   Jun       FY 17
# 1780                                  LEGO Crew  06/30/2017   Jun       FY 17
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                1781 non-null   object
#  1   Date                 1781 non-null   object
#  2   Month                1781 non-null   object
#  3   Fiscal Year          1781 non-null   object
#  4   Library              1781 non-null   object
#  5   Primary Event Type   1781 non-null   object
#  6   Event Type Option 1  1781 non-null   object
#  7   Event Type Option 2  333 non-null    object
#  8   Primary Age Group    1781 non-null   object
#  9   Age Group Option 1   987 non-null    object
#  10  Age Group Option 2   67 non-null     object
#  11  Description          1781 non-null   object
#  12  Internal Notes       16 non-null     object
#  13  Published Status     1781 non-null   object
#  14  Attendance           1412 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Attendance
# count  1412.000000
# mean     38.857649
# std      27.602966
# min       0.000000
# 25%      17.000000
# 50%      34.000000
# 75%      55.000000
# max     176.000000

# %%
df.Attendance.describe()
# Out:
# count    1412.000000
# mean       38.857649
# std        27.602966
# min         0.000000
# 25%        17.000000
# 50%        34.000000
# 75%        55.000000
# max       176.000000
# Name: Attendance, dtype: float64

# %%
df[['Age Group Option 1','Description']].describe()
# Out:
#                 Age Group Option 1  \
# count                          987
# unique                           6
# top     Preschool and Kindergarten
# freq                           375
#
#                                               Description
# count                                                1781
# unique                                                192
# top     Tutors from Growing Together are here to assis...
# freq                                                  239

# %%
df.Attendance.hist()
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.boxplot('Attendance')
# Out:
# <Axes: >

# %%
df.charges.hist()

# %%
df.Attendance.plot.bar()
# Out:
# <Axes: >

# %%
df['Attendance'].plot.bar()
# Out:
# <Axes: >

# %%
df.dropna(axis=1)
# Out:
#                                           Title        Date Month Fiscal Year  \
# 0                   Me and You-kelele Storytime  07/01/2016   Jul       FY 17
# 1     MC Infants & Toddlers Bilingual Storytime  07/01/2016   Jul       FY 17
# 2                                  lego weekend  07/01/2016   Jul       FY 17
# 3                                 LEGO Playtime  07/01/2016   Jul       FY 17
# 4                                     LEGO Crew  07/01/2016   Jul       FY 17
# ...                                         ...         ...   ...         ...
# 1776                                 Act it Out  06/29/2017   Jun       FY 17
# 1777  MC Infants & Toddlers Bilingual Storytime  06/30/2017   Jun       FY 17
# 1778                     Lego Construction Crew  06/30/2017   Jun       FY 17
# 1779                    LEGO and DUPLO Playtime  06/30/2017   Jun       FY 17
# 1780                                  LEGO Crew  06/30/2017   Jun       FY 17
#
# ...

# %%
df.isnull()
# Out:
#       Title   Date  Month  Fiscal Year  Library  Primary Event Type  \
# 0     False  False  False        False    False               False
# 1     False  False  False        False    False               False
# 2     False  False  False        False    False               False
# 3     False  False  False        False    False               False
# 4     False  False  False        False    False               False
# ...     ...    ...    ...          ...      ...                 ...
# 1776  False  False  False        False    False               False
# 1777  False  False  False        False    False               False
# 1778  False  False  False        False    False               False
# 1779  False  False  False        False    False               False
# 1780  False  False  False        False    False               False
#
#       Event Type Option 1  Event Type Option 2  Primary Age Group  \
# 0                   False                 True              False
# ...

# %%
df.isnull().sum()
# Out:
# Title                     0
# Date                      0
# Month                     0
# Fiscal Year               0
# Library                   0
# Primary Event Type        0
# Event Type Option 1       0
# Event Type Option 2    1448
# Primary Age Group         0
# Age Group Option 1      794
# Age Group Option 2     1714
# Description               0
# Internal Notes         1765
# Published Status          0
# Attendance              369
# dtype: int64

# %%
df.Attendance.isnull()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1776    False
# 1777    False
# 1778    False
# 1779     True
# 1780    False
# Name: Attendance, Length: 1781, dtype: bool
