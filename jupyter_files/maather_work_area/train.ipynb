# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("../../dataset/laptopData.csv")
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns='Unnamed: 0', axis=1, inplace=True)
df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42)
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                Memory  \
# ...

# %%
df_test
# Out:
#       Company            TypeName Inches  \
# 479   Toshiba            Notebook   13.3
# 1022       HP            Notebook   13.3
# 298    Lenovo            Notebook   15.6
# 1265   Lenovo            Notebook   15.6
# 774       NaN                 NaN    NaN
# ...       ...                 ...    ...
# 672    Lenovo  2 in 1 Convertible   13.3
# 506      Asus            Notebook   15.6
# 668   Toshiba            Notebook   15.6
# 778     Razer              Gaming     14
# 723      Dell              Gaming   17.3
#
#                                ScreenResolution                          Cpu  \
# 479                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1022                IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 298                           Full HD 1920x1080  AMD A10-Series 9600P 2.4GHz
# 1265                IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 774                                         NaN                          NaN
# ...

# %%
df_test = df_test.dropna()
df_train = df_train.dropna()

# %%
df_train.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
memory_split_train = df_train['Memory'].str.extract(r'(\d+[GB|TB]+) ([A-Za-z ]+)')
memory_split_train[memory_split_train.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
df_train['Memory_Size'] = memory_split_train[0]
df_train['Memory_Type'] = memory_split_train[1]
# Drop the original 'Memory' column
df_train = df_train.drop('Memory', axis=1)
# Out:
# C:\Users\71526\AppData\Local\Temp\ipykernel_27436\3519727062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Memory_Size'] = memory_split_train[0]
# C:\Users\71526\AppData\Local\Temp\ipykernel_27436\3519727062.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Memory_Type'] = memory_split_train[1]

# %%
memory_split_test = df_test['Memory'].str.extract(r'(\d+[GB|TB]+) ([A-Za-z ]+)')
memory_split_test[memory_split_test.isnull().any(axis=1)]
# Out:
#        0    1
# 770  NaN  NaN

# %%
memory_split_test.loc[770, 0] = '512GB'
memory_split_test.loc[770, 1] = 'SSD'

# %%
df_test['Memory_Size'] = memory_split_test[0]
df_test['Memory_Type'] = memory_split_test[1]
# Drop the original 'Memory' column
df_test = df_test.drop('Memory', axis=1)
# Out:
# C:\Users\71526\AppData\Local\Temp\ipykernel_27436\2803151512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Memory_Size'] = memory_split_test[0]
# C:\Users\71526\AppData\Local\Temp\ipykernel_27436\2803151512.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['Memory_Type'] = memory_split_test[1]

# %%
df_train['Ram'] = df_train['Ram'].str.replace('GB', '').fillna(0).astype(int)
df_test['Ram'] = df_test['Ram'].str.replace('GB', '').fillna(0).astype(int)

# %%
df_train.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# dtype: int64

# %%
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                      Gpu       OpSys  \
# ...

# %%
# extract CPU clock speed and convert to numeric
df_train['Cpu_Speed'] = df_train['Cpu'].str.extract(r'(\d+\.\d+)GHz').astype(float)
# df_train.replace('?', np.nan, inplace=True)

# %%
df_train.head()
# Out:
#      Company   TypeName Inches             ScreenResolution  \
# 1158  Lenovo   Notebook   15.6            Full HD 1920x1080
# 904   Lenovo   Notebook   15.6  IPS Panel Full HD 1920x1080
# 439     Asus   Notebook   15.6            Full HD 1920x1080
# 581     Dell   Notebook   15.6                     1366x768
# 676     Asus  Ultrabook     14            Full HD 1920x1080
#
#                              Cpu  Ram                    Gpu       OpSys  \
# 1158  Intel Core i5 6200U 2.3GHz    8     AMD Radeon R5 M330  Windows 10
# 904   Intel Core i5 7200U 2.5GHz    8  Intel HD Graphics 620  Windows 10
# 439   Intel Core i5 7200U 2.5GHz    4  Intel HD Graphics 620       Linux
# 581   Intel Core i5 7300U 2.6GHz    8  Intel HD Graphics 620  Windows 10
# 676   Intel Core i5 7200U 2.5GHz    8  Intel HD Graphics 620  Windows 10
#
#       Weight        Price Memory_Size Memory_Type  Cpu_Speed
# 1158   2.5kg   42010.7472         0TB      Hybrid        2.3
# ...

# %%
df_test['Cpu_Speed'] = df_test['Cpu'].str.extract(r'(\d+\.\d+)GHz').astype(float)
# df_test = df_test.replace('?', np.nan, inplace=True)

# %%
df_test.head()
# Out:
#       Company  TypeName Inches             ScreenResolution  \
# 479   Toshiba  Notebook   13.3  IPS Panel Full HD 1920x1080
# 1022       HP  Notebook   13.3  IPS Panel Full HD 1920x1080
# 298    Lenovo  Notebook   15.6            Full HD 1920x1080
# 1265   Lenovo  Notebook   15.6  IPS Panel Full HD 1920x1080
# 582        HP  Notebook   13.3            Full HD 1920x1080
#
#                               Cpu  Ram                      Gpu       OpSys  \
# 479    Intel Core i5 7200U 2.5GHz    8    Intel HD Graphics 620  Windows 10
# 1022   Intel Core i5 7200U 2.5GHz    8    Intel HD Graphics 620  Windows 10
# 298   AMD A10-Series 9600P 2.4GHz    6        AMD Radeon R5 430  Windows 10
# 1265  Intel Core i7 6700HQ 2.6GHz    8  Nvidia GeForce GTX 960M  Windows 10
# 582    Intel Core i3 7100U 2.4GHz    4    Intel HD Graphics 620  Windows 10
#
#       Weight     Price Memory_Size Memory_Type  Cpu_Speed
# 479   1.05kg  89084.16       256GB         SSD        2.5
# ...

# %%
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                      Gpu       OpSys  \
# ...

# %%
categorical_train = df_train.select_dtypes(exclude = np.number).columns

# %%
categorical_test = df_test.select_dtypes(exclude = np.number).columns

# %%
df1_train= df_train.copy()
classes = dict()
le = LabelEncoder()
for col in categorical_train:
    df1_train[col]= le.fit_transform(df1_train[col])
    classes[col] = le.classes_

df1_train
# Out:
#       Company  TypeName  Inches  ScreenResolution  Cpu  Ram  Gpu  OpSys  \
# 1158       10         3      14                 8   56    8   15      5
# 904        10         3      14                14   61    8   43      5
# 439         2         3      14                 8   61    4   43      2
# 581         4         3      14                 0   64    8   43      5
# 676         2         4      10                 8   61    8   43      5
# ...       ...       ...     ...               ...  ...  ...  ...    ...
# 1095        0         3      14                 8   61    8   73      5
# 1130        7         3      14                 0   82    8   43      5
# 1294        7         3      14                 8   10    6   20      5
# 860        10         3      14                14   61    8   43      5
# 1126       10         0       0                25   23    4   32      5
#
#       Weight        Price  Memory_Size  Memory_Type  Cpu_Speed
# ...

# %%
df1_test= df_test.copy()
classes = dict()
le = LabelEncoder()
for col in categorical_test:
    df1_test[col]= le.fit_transform(df1_test[col])
    classes[col] = le.classes_

df1_test
# Out:
#       Company  TypeName  Inches  ScreenResolution  Cpu  Ram  Gpu  OpSys  \
# 479        15         3       5                12   38    8   32      4
# 1022        6         3       5                12   38    8   32      4
# 298         9         3       9                 6    0    6   10      4
# 1265        9         3       9                12   49    8   56      4
# 582         6         3       5                 6   29    4   32      4
# ...       ...       ...     ...               ...  ...  ...  ...    ...
# 672         9         0       5                10   38    8   32      4
# 506         2         3       9                 6   53    8   32      4
# 668        15         3       9                12   38    8   32      4
# 778        13         1       8                 6   56   16   51      4
# 723         3         1      10                 4   56   32   52      4
#
#       Weight       Price  Memory_Size  Memory_Type  Cpu_Speed
# ...

# %%
df1_test = df1_test.dropna()
df1_train = df1_train.dropna()

# %%
X_train= df1_train.drop(columns='Price').values
y_train = df1_train['Price'].values

X_test = df1_test.drop(columns='Price').values
y_test = df1_test['Price'].values

# %%
reg = LinearRegression() # ols
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)
y_pred[:10]
# Out:
# array([63757.43432614, 62226.9902686 , 19395.79111045, 55156.48077789,
#        35995.47296819, 57319.76739658, 12555.80411356, 88086.98471231,
#        31625.05629609, 49871.19223436])

# %%
y_test[:10]
# Out:
# array([ 89084.16,  61218.72,  26586.72,  47898.72,  38308.32,  63456.48,
#         18594.72, 101178.72,  38681.28,  96596.64])

# %%
np.mean(np.square(y_test - y_pred))
# Out:
# 663875859.8800799

# %%
np.mean(np.absolute(y_test - y_pred))
# Out:
# 16306.274734828363

# %%
y_mean = np.mean(y_test)
TSS = np.sum(np.square(y_test - y_mean))
RSS = np.sum(np.square(y_test - y_pred))
1- RSS/ TSS
# Out:
# 0.569266854140894

# %%
np.mean(np.abs(y_pred-y_test))
# Out:
# 16306.274734828363

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred)
# Out:
# (0.569266854140894, 663875859.8800799, 16306.274734828363)

# %%
y_bar = np.mean(y_test)
1 - np.sum(np.square(y_pred-y_test))/np.sum(np.square(y_test-y_bar))
# Out:
# 0.569266854140894
