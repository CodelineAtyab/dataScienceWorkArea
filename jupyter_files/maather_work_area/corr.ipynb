# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sb
from mpl_toolkits.mplot3d import Axes3D

# %%
#get the covariance matrix
df = pd.read_csv('dogs-ranking-dataset.csv')
df.select_dtypes(include=np.number).corr()
# Out:
#                                score  popularity ranking      size  \
# score                       1.000000            0.015224 -0.505688
# popularity ranking          0.015224            1.000000  0.074112
# size                       -0.505688            0.074112  1.000000
# score for kids              0.851044            0.043583 -0.317110
# INTELLIGENCE RANK          -0.476499            0.179975 -0.092807
# LONGEVITY(YEARS)            0.811903            0.059796 -0.585048
# NUMBER OF GENETIC AILMENTS -0.240560           -0.515608  0.122606
# SUITABILITY FOR CHILDREN    0.073822           -0.084113 -0.226501
#
#                             score for kids  INTELLIGENCE RANK  \
# score                             0.851044          -0.476499
# popularity ranking                0.043583           0.179975
# size                             -0.317110          -0.092807
# score for kids                    1.000000          -0.461114
# ...

# %%
corr = df.select_dtypes(include=np.number).corr()
dataplot = sb.heatmap(corr, annot=True)
plt.show()

# %%
df
# Out:
#                      Breed          type  score  popularity ranking  size  \
# 0           Border Terrier       terrier   3.61                  61     1
# 1            Cairn Terrier       terrier   3.53                  48     1
# 2           Siberian Husky       working   3.22                  16     2
# 3   Welsh Springer Spaniel      sporting   3.34                  81     2
# 4   English Cocker Spaniel      sporting   3.33                  51     2
# ..                     ...           ...    ...                 ...   ...
# 82        Alaskan Malamute       working   1.82                  47     3
# 83              Bloodhound         hound   1.66                  42     3
# 84               Chow Chow  non-sporting   1.76                  54     2
# 85                   Akita       working   1.95                  41     3
# 86                 Bulldog  non-sporting   0.99                   6     2
#
#      intelligence                        congential ailments  score for kids  \
# ...

# %%
# list breeds
breeds = df['Breed'].unique()
breeds
# Out:
# array(['Border Terrier', 'Cairn Terrier', 'Siberian Husky',
#        'Welsh Springer Spaniel', 'English Cocker Spaniel',
#        'Cocker Spaniel', 'Lhasa Apso', 'English Springer Spaniel',
#        'Shetland Sheepdog', 'West Highland White Terrier', 'Brittany',
#        'German Shorthaired Pointer', 'Pointer', 'Tibetan Spaniel',
#        'Labrador Retriever', 'Bichon Frise', 'Irish Setter', 'Samoyed',
#        'Shih Tzu', 'Golden Retriever', 'Chesapeake Bay Retriever',
#        'Papillon', 'Gordon Setter', 'English Setter', 'Pug',
#        'Affenpinscher', 'Miniature Schnauzer', 'Beagle', 'Border Collie',
#        'Australian Terrier', 'Whippet', 'Boston Terrier', 'Briard',
#        'Bedlington Terrier', 'Cavalier King Charles Spaniel', 'Dalmatian',
#        'Flat-Coated Retriever', 'Belgian Tervuren', 'Basset Hound',
#        'Poodle', 'Staffordshire Bull Terrier', 'Bouvier des Flandres',
#        'Pembroke Welsh Corgi', 'Clumber Spaniel', 'Pomeranian',
# ...

# %%
# plot data for each breed
plt.figure(figsize=(30, 20))
plt.bar(df['Breed'], df['score'])
plt.ylabel('score')
plt.xlabel('breed')
plt.title('score vs breed')
plt.show()

# %%
# get data for german shepherd
german_shepherd = df[df['Breed'] == 'German Shepherd']
german_shepherd
# Out:
#               Breed     type  score  popularity ranking  size intelligence  \
# 72  German Shepherd  herding   2.06                   2     3    Brightest
#
#                                  congential ailments  score for kids size.1  \
# 72  nerves, pancreas, blood (hemophilia), hip joints            2.94  large
#
#    $LIFETIME COST  INTELLIGENCE RANK INTELLIGENCE %  LONGEVITY(YEARS)  \
# 72       $17,416                   3            98%              9.73
#
#     NUMBER OF GENETIC AILMENTS  \
# 72                           8
#
#                                     GENETIC AILMENTS PURCHASE PRICE  \
# 72  nerves, pancreas, blood (hemophilia), hip joints          $820
#
#    FOOD COSTS PER YEAR GROOMING FREQUNCY  SUITABILITY FOR CHILDREN
# 72               $466        Once a week                         2

# %%
# list dogs with highest intelligence
highest_intelligence = df.sort_values(by='INTELLIGENCE RANK', ascending=True)
highest_intelligence
# Out:
#                 Breed          type  score  popularity ranking  size  \
# 28      Border Collie       herding   3.64                  39     2
# 39             Poodle  non-sporting   3.04                   8     2
# 72    German Shepherd       herding   2.06                   2     3
# 19   Golden Retriever      sporting   2.80                   4     2
# 55  Doberman Pinscher       working   2.59                  13     3
# ..                ...           ...    ...                 ...   ...
# 81             Borzoi         hound   1.89                  71     3
# 84          Chow Chow  non-sporting   1.76                  54     2
# 86            Bulldog  non-sporting   0.99                   6     2
# 58            Basenji         hound   2.51                  68     2
# 59       Afghan Hound         hound   2.08                  66     3
#
#    intelligence                               congential ailments  \
# 28    Brightest                            eye problems, deafness
# ...

# %%
sb.pairplot(df, hue='size')

# %%
df['size'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='size'>

# %%
smallest = df[df['size'] == 1].score.mean()
largest = df[df['size'] == 3].score.mean()
plt.bar(['smallest', 'largest'], [smallest, largest])
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(df.intelligence.unique(), df.intelligence.value_counts())
plt.title('Intelligence distribution')
# Out:
# Text(0.5, 1.0, 'Intelligence distribution')

# %%
# plot the relationship between size and intelligence precentage 
plt.bar(df['INTELLIGENCE %'], df['size'])
plt.xlabel('Intelligence %')
plt.ylabel('size')
plt.title('Intelligence Rank vs size')
# Out:
# Text(0.5, 1.0, 'Intelligence Rank vs size')

# %%
fig = px.scatter_3d(df, x='Size', y='score', z='INTELLIGENCE %', color='Breed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 fig = px.scatter_3d(df, x='Size', y='score', z='INTELLIGENCE %', color='Breed')
#
# NameError: name 'px' is not defined
