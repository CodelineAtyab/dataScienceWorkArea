# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv('laptopData.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df_copy = df.copy()

# %%
df_train, df_test = train_test_split(df, test_size=0.3, random_state=42)
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                Memory  \
# ...

# %%
df_train = df_train.dropna()
df_train
# Out:
#      Company            TypeName Inches                 ScreenResolution  \
# 1158  Lenovo            Notebook   15.6                Full HD 1920x1080
# 904   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 439     Asus            Notebook   15.6                Full HD 1920x1080
# 581     Dell            Notebook   15.6                         1366x768
# 676     Asus           Ultrabook     14                Full HD 1920x1080
# ...      ...                 ...    ...                              ...
# 1095    Acer            Notebook   15.6                Full HD 1920x1080
# 1130      HP            Notebook   15.6                         1366x768
# 1294      HP            Notebook   15.6                Full HD 1920x1080
# 860   Lenovo            Notebook   15.6      IPS Panel Full HD 1920x1080
# 1126  Lenovo  2 in 1 Convertible   10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram                Memory  \
# ...

# %%
df_test = df_test.dropna()
df_test
# Out:
#       Company            TypeName Inches  \
# 479   Toshiba            Notebook   13.3
# 1022       HP            Notebook   13.3
# 298    Lenovo            Notebook   15.6
# 1265   Lenovo            Notebook   15.6
# 582        HP            Notebook   13.3
# ...       ...                 ...    ...
# 672    Lenovo  2 in 1 Convertible   13.3
# 506      Asus            Notebook   15.6
# 668   Toshiba            Notebook   15.6
# 778     Razer              Gaming     14
# 723      Dell              Gaming   17.3
#
#                                ScreenResolution                          Cpu  \
# 479                 IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1022                IPS Panel Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 298                           Full HD 1920x1080  AMD A10-Series 9600P 2.4GHz
# 1265                IPS Panel Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz
# 582                           Full HD 1920x1080   Intel Core i3 7100U 2.4GHz
# ...

# %%
# Clean the 'Weight' column and convert to float
df_train['Weight'] = df_train['Weight'].str.replace('kg', '')
df_train['Weight'] = pd.to_numeric(df_train['Weight'], errors='coerce')
# Out:
# C:\Users\71518\AppData\Local\Temp\ipykernel_11328\1546289355.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Weight'] = df_train['Weight'].str.replace('kg', '')
# C:\Users\71518\AppData\Local\Temp\ipykernel_11328\1546289355.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Weight'] = pd.to_numeric(df_train['Weight'], errors='coerce')

# %%
# Clean the 'Weight' column and convert to float
df_test['Weight'] = df_test['Weight'].str.replace('kg', '')
df_test['Weight'] = pd.to_numeric(df_test['Weight'], errors='coerce')

# %%
df_train[df_train['Weight'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
df_test[df_test['Weight'].isnull()]
# Out:
#     Company   TypeName Inches   ScreenResolution                         Cpu  \
# 208    Dell  Ultrabook   13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#      Ram     Memory                     Gpu       OpSys  Weight     Price
# 208  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10     NaN  77202.72

# %%
df_test.loc[208, 'Weight'] = 2.8

# %%
# Extract memory size and type
memory_split_train = df_train['Memory'].str.extract(r'(\d+[GB|TB]+) ([A-Za-z ]+)')

# %%
memory_split_train[memory_split_train.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
df_train['Memory_Size'] = memory_split_train[0]
df_train['Memory_Type'] = memory_split_train[1]
# Out:
# C:\Users\71518\AppData\Local\Temp\ipykernel_11328\2562497959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Memory_Size'] = memory_split_train[0]
# C:\Users\71518\AppData\Local\Temp\ipykernel_11328\2562497959.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train['Memory_Type'] = memory_split_train[1]

# %%
# Drop the original 'Memory' column
df_train = df_train.drop('Memory', axis=1)

# %%
memory_split_test = df_test['Memory'].str.extract(r'(\d+[GB|TB]+) ([A-Za-z ]+)')

# %%
memory_split_test[memory_split_test.isnull().any(axis=1)]
# Out:
#        0    1
# 770  NaN  NaN

# %%
memory_split_test.loc[770, 0] = '512GB'
memory_split_test.loc[770, 1] = 'SSD'

# %%
df_test['Memory_Size'] = memory_split_test[0]
df_test['Memory_Type'] = memory_split_test[1]

# %%
# Drop the original 'Memory' column
df_test = df_test.drop('Memory', axis=1)

# %%
# Function to split Cpu column into CPUModel and CPUClockSpeed
def split_cpu_info(cpu):
    parts = cpu.split()
    
    cpu_model = ' '.join(parts[:len(parts)-1])
    cpu_clock_speed = parts[-1]
    
    return pd.Series([cpu_model, cpu_clock_speed], index=['CPUModel', 'CPUClockSpeed'])

# %%
# Apply the function to split Cpu column and assign to new columns
df_train[['CPUModel', 'CPUClockSpeed']] = df_train['Cpu'].apply(split_cpu_info)
df_train = df_train.drop('Cpu', axis=1)

# %%
# Apply the function to split Cpu column and assign to new columns
df_test[['CPUModel', 'CPUClockSpeed']] = df_test['Cpu'].apply(split_cpu_info)
df_test = df_test.drop('Cpu', axis=1)

# %%
df_train.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# CPUModel            0
# CPUClockSpeed       0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# CPUModel            0
# CPUClockSpeed       0
# dtype: int64

# %%
# Clean the 'CPUClockSpeed' column and convert to float
df_train['CPUClockSpeed'] = df_train['CPUClockSpeed'].str.replace('GHz', '')
df_train['CPUClockSpeed'] = pd.to_numeric(df_train['CPUClockSpeed'], errors='coerce')

# %%
# Clean the 'CPUClockSpeed' column and convert to float
df_test['CPUClockSpeed'] = df_test['CPUClockSpeed'].str.replace('GHz', '')
df_test['CPUClockSpeed'] = pd.to_numeric(df_test['CPUClockSpeed'], errors='coerce')

# %%
df_train.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# CPUModel            0
# CPUClockSpeed       0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# CPUModel            0
# CPUClockSpeed       0
# dtype: int64

# %%
# Clean the 'Ram' column and convert to float
df_train['Ram'] = df_train['Ram'].str.replace('GB', '')
df_train['Ram'] = pd.to_numeric(df_train['Ram'], errors='coerce')

# %%
# Clean the 'Ram' column and convert to float
df_test['Ram'] = df_test['Ram'].str.replace('GB', '')
df_test['Ram'] = pd.to_numeric(df_test['Ram'], errors='coerce')

# %%
# Function to convert Memory sizes to numerical values in GB
def convert_memory_size(memory):
    if 'GB' in memory:
        # Extract numeric part and convert to float
        numeric_part = memory.split('GB')[0].strip()
        numeric_value = float(numeric_part)
        return numeric_value
    elif 'TB' in memory:
        # Convert TB to GB (1 TB = 1024 GB)
        numeric_part = memory.split('TB')[0].strip()
        numeric_value = float(numeric_part) * 1024
        return numeric_value
    else:
        return None  # Handle cases where format doesn't match

# %%
# Apply the function to convert Memory sizes to numerical values in GB
df_train['Memory_Size'] = df_train['Memory_Size'].apply(convert_memory_size)

# %%
# Apply the function to convert Memory sizes to numerical values in GB
df_test['Memory_Size'] = df_test['Memory_Size'].apply(convert_memory_size)

# %%
# Function to extract GPU company from Gpu column
def extract_gpu_company(gpu):
    return gpu.split()[0]

# %%
# Apply the function to extract GPU company and create a new column
df_train['GPU_Company'] = df_train['Gpu'].apply(extract_gpu_company)

# %%
# Apply the function to extract GPU company and create a new column
df_test['GPU_Company'] = df_test['Gpu'].apply(extract_gpu_company)

# %%
# Function to process ScreenResolution column
def process_screen_resolution(resolution):
    parts = resolution.split()
    
    # Check if there are additional descriptors
    if len(parts) > 1:
        screen_resolution = parts[-1]  # Last part is the resolution
        screen_type = ' '.join(parts[:-1])  # Join remaining parts as Screen_Type
    else:
        screen_resolution = resolution
        width, height = map(int, screen_resolution.split('x'))
        if width >= 1920 and height >= 1080:
            screen_type = 'Full HD'
        elif width >= 1600 and height >= 900:
            screen_type = 'HD+'
        else:
            screen_type = 'Other'  # Adjust as per your specific criteria
    
    return pd.Series([screen_resolution, screen_type], index=['ScreenResolution', 'Screen_Type'])

# %%
# Apply the function and create new columns
df_train[['ScreenResolution', 'Screen_Type']] = df_train['ScreenResolution'].apply(process_screen_resolution)

# %%
# Apply the function and create new columns
df_test[['ScreenResolution', 'Screen_Type']] = df_test['ScreenResolution'].apply(process_screen_resolution)

# %%
df_train.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# CPUModel            0
# CPUClockSpeed       0
# GPU_Company         0
# Screen_Type         0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Ram                 0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# Memory_Size         0
# Memory_Type         0
# CPUModel            0
# CPUClockSpeed       0
# GPU_Company         0
# Screen_Type         0
# dtype: int64

# %%
# Split the screen_resolution column into width and height columns
df_train[['width', 'height']] = df_train['ScreenResolution'].str.split('x', expand=True)

# Convert width and height columns to numerical values
df_train['width'] = pd.to_numeric(df_train['width'])
df_train['height'] = pd.to_numeric(df_train['height'])

# Drop the original screen_resolution column if no longer needed
df_train.drop('ScreenResolution', axis=1, inplace=True)

# %%
# Split the screen_resolution column into width and height columns
df_test[['width', 'height']] = df_test['ScreenResolution'].str.split('x', expand=True)

# Convert width and height columns to numerical values
df_test['width'] = pd.to_numeric(df_test['width'])
df_test['height'] = pd.to_numeric(df_test['height'])

# Drop the original screen_resolution column if no longer needed
df_test.drop('ScreenResolution', axis=1, inplace=True)

# %%
df_train
# Out:
#      Company            TypeName Inches  Ram                      Gpu  \
# 1158  Lenovo            Notebook   15.6    8       AMD Radeon R5 M330
# 904   Lenovo            Notebook   15.6    8    Intel HD Graphics 620
# 439     Asus            Notebook   15.6    4    Intel HD Graphics 620
# 581     Dell            Notebook   15.6    8    Intel HD Graphics 620
# 676     Asus           Ultrabook     14    8    Intel HD Graphics 620
# ...      ...                 ...    ...  ...                      ...
# 1095    Acer            Notebook   15.6    8  Nvidia GeForce GTX 950M
# 1130      HP            Notebook   15.6    8    Intel HD Graphics 620
# 1294      HP            Notebook   15.6    6       AMD Radeon R7 M440
# 860   Lenovo            Notebook   15.6    8    Intel HD Graphics 620
# 1126  Lenovo  2 in 1 Convertible   10.1    4    Intel HD Graphics 400
#
#            OpSys  Weight        Price  Memory_Size    Memory_Type  \
# ...

# %%
train_categorical = df_train.select_dtypes(exclude = np.number).columns
train_categorical
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Gpu', 'OpSys', 'Memory_Type',
#        'CPUModel', 'GPU_Company', 'Screen_Type'],
#       dtype='object')

# %%
classes = dict()
le = LabelEncoder()
for col in train_categorical:
    df_train[col]= le.fit_transform(df_train[col])
    classes[col] = le.classes_

# %%
df_train
# Out:
#       Company  TypeName  Inches  Ram  Gpu  OpSys  Weight        Price  \
# 1158       10         3      14    8   15      5    2.50   42010.7472
# 904        10         3      14    8   43      5    1.95  104588.1072
# 439         2         3      14    4   43      2    2.00   29783.5200
# 581         4         3      14    8   43      5    1.90   53733.9456
# 676         2         4      10    8   43      5    1.10   60472.8000
# ...       ...       ...     ...  ...  ...    ...     ...          ...
# 1095        0         3      14    8   73      5    2.40   42570.7200
# 1130        7         3      14    8   43      5    2.04   33513.1200
# 1294        7         3      14    6   20      5    2.04   29303.4672
# 860        10         3      14    8   43      5    2.30   45323.1648
# 1126       10         0       0    4   32      5    0.69   25521.1200
#
#       Memory_Size  Memory_Type  CPUModel  CPUClockSpeed  GPU_Company  \
# ...

# %%
test_categorical = df_test.select_dtypes(exclude = np.number).columns
test_categorical
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Gpu', 'OpSys', 'Memory_Type',
#        'CPUModel', 'GPU_Company', 'Screen_Type'],
#       dtype='object')

# %%
classes = dict()
le = LabelEncoder()
for col in test_categorical:
    df_test[col]= le.fit_transform(df_test[col])
    classes[col] = le.classes_

# %%
df_test
# Out:
#       Company  TypeName  Inches  Ram  Gpu  OpSys  Weight       Price  \
# 479        15         3       5    8   32      4    1.05   89084.160
# 1022        6         3       5    8   32      4    1.11   61218.720
# 298         9         3       9    6   10      4    2.40   26586.720
# 1265        9         3       9    8   56      4    2.60   47898.720
# 582         6         3       5    4   32      4    1.49   38308.320
# ...       ...       ...     ...  ...  ...    ...     ...         ...
# 672         9         0       5    8   32      4    1.30   55091.520
# 506         2         3       9    8   32      4    2.00   65214.720
# 668        15         3       9    8   32      4    2.00   67026.240
# 778        13         1       8   16   51      4    1.95  154458.720
# 723         3         1      10   32   52      4    4.36  194972.832
#
#       Memory_Size  Memory_Type  CPUModel  CPUClockSpeed  GPU_Company  \
# ...

# %%
df_train.isnull().sum()
# Out:
# Company          0
# TypeName         0
# Inches           0
# Ram              0
# Gpu              0
# OpSys            0
# Weight           0
# Price            0
# Memory_Size      0
# Memory_Type      0
# CPUModel         0
# CPUClockSpeed    0
# GPU_Company      0
# Screen_Type      0
# width            0
# height           0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Company          0
# TypeName         0
# Inches           0
# Ram              0
# Gpu              0
# OpSys            0
# Weight           0
# Price            0
# Memory_Size      0
# Memory_Type      0
# CPUModel         0
# CPUClockSpeed    0
# GPU_Company      0
# Screen_Type      0
# width            0
# height           0
# dtype: int64

# %% [markdown]
# ## LinearRegression

# %%
x_train, y_train = df_train.drop(columns= 'Price').values, df_train['Price'].values

# %%
x_test, y_test = df_test.drop(columns= 'Price').values, df_test['Price'].values

# %%
reg = LinearRegression() # ols
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
y_pred[:10]
# Out:
# array([ 68319.28638507,  64361.33974489,  32042.59742061,  67288.1193651 ,
#         49331.93731598,  33292.86836004,  71282.42624865,  16770.7559491 ,
#        122712.44527488,  39152.25549463])

# %%
y_test[:10]
# Out:
# array([ 89084.16,  61218.72,  26586.72,  47898.72,  38308.32,  24455.52,
#         63456.48,  18594.72, 101178.72,  38681.28])

# %%
np.mean(np.square(y_test - y_pred))
# Out:
# 502990729.70713264

# %%
np.mean(np.absolute(y_test - y_pred))
# Out:
# 14939.531641977434

# %%
y_mean = np.mean(y_test)
TSS = np.sum(np.square(y_test - y_mean))
RSS = np.sum(np.square(y_test - y_pred))
1- RSS/ TSS
# Out:
# 0.6725006617268887

# %%
np.mean(np.abs(y_pred-y_test))
# Out:
# 14939.531641977434

# %%
r2_score(y_test, y_pred), mean_squared_error(y_test, y_pred), mean_absolute_error(y_test, y_pred)
# Out:
# (0.6725006617268887, 502990729.70713264, 14939.531641977434)

# %%
y_bar = np.mean(y_test)
1 - np.sum(np.square(y_pred-y_test))/np.sum(np.square(y_test-y_bar))
# Out:
# 0.6725006617268887

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha=1.0)
ridge_reg.fit(x_train, y_train)
y_pred_ridge = ridge_reg.predict(x_test)

# %%
r2_score(y_test, y_pred_ridge), mean_squared_error(y_test, y_pred_ridge), mean_absolute_error(y_test, y_pred_ridge)
# Out:
# (0.6723816957401159, 503173443.9343209, 14939.150796533702)
